# %%
import kmapper as km
from kmapper import Cover, jupyter
import numpy as np

from sklearn.datasets import fetch_20newsgroups
from sklearn.cluster import AgglomerativeClustering
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import Isomap
from sklearn.preprocessing import MinMaxScaler

# %%
import pandas as pd

import math
import numpy as np


#raw_data = pd.read_csv(r'C:\Users\BRIGHT\raw.csv')
#raw_data.head()


path_1 = r'C:\Users\BRIGHT\BBCdata.csv'
df_1 = pd.read_csv(path_1)
df_1.head()
# Out:
#    ID  Live_Alone groupedmaritalstatus Lonelycategrical  \
# 0  29           1                 1.00             1.00
# 1  32           1                 1.00             2.00
# 2  33         -99               #NULL!           #NULL!
# 3  34           1                 1.00             1.00
# 4  35         -99               #NULL!           #NULL!
#
#   positivelonelinessgrouped groupedtimealone groupedhealth
# 0                    #NULL!             2.00          1.00
# 1                      1.00             2.00          1.00
# 2                    #NULL!           #NULL!        #NULL!
# 3                      2.00             1.00          2.00
# 4                    #NULL!           #NULL!        #NULL!

# %%
df_1.shape
# Out:
# (55060, 7)

# %%
import numpy as np

df_1 = df_1.replace("#NULL!	", np.NaN)

#df_1 = df_1.replace(np.NaN, 0 , inplace=True)

# %%
df_1.head()
# Out:
#    ID  Live_Alone groupedmaritalstatus Lonelycategrical  \
# 0  29           1                 1.00             1.00
# 1  32           1                 1.00             2.00
# 2  33         -99               #NULL!           #NULL!
# 3  34           1                 1.00             1.00
# 4  35         -99               #NULL!           #NULL!
#
#   positivelonelinessgrouped groupedtimealone groupedhealth
# 0                    #NULL!             2.00          1.00
# 1                      1.00             2.00          1.00
# 2                    #NULL!           #NULL!        #NULL!
# 3                      2.00             1.00          2.00
# 4                    #NULL!           #NULL!        #NULL!

# %% [markdown]
# ## I encoded the file with (encoding="ISO-8859-1") for my CSV file that took 3 hours

# %%
path_2 = r'C:\Users\BRIGHT\raw.csv'
df_2 = pd.read_csv(path_2)  # , encoding="ISO-8859-1")
# df_2.head()

# %%
df_1.replace("#NULL!", "0", inplace=True)

# %%
 df_2
# Out:
#            F  gender   age                         Q9_Loneliness_Meaning_Qual
# 0         29     1.0  89.0  time to reflect on close family affairs, time ...
# 1         30     2.0  44.0                                                -99
# 2         31     NaN   NaN                                                -99
# 3         32     2.0  63.0  Not fitting in; sad; distant emotionally from ...
# 4         33     NaN   NaN                                                -99
# ...      ...     ...   ...                                                ...
# 55198  55227     NaN   NaN                                                -99
# 55199  55228     NaN   NaN                                                -99
# 55200  55229     NaN   NaN                                                -99
# 55201  55230     NaN   NaN                                                -99
# 55202  55231     NaN   NaN                                                -99
#
# [55203 rows x 4 columns]

# %%
# Renaming column

clean_data = df_2.rename(columns = {'Q9_Loneliness_Meaning_Qual': 'response'})

# %%
clean_data = clean_data[clean_data['response'].notnull()]

# %%
 from nltk.corpus import stopwords
stop = stopwords.words('english')

 clean_data["response"] = clean_data["response"].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

# %%
clean_data['response'] = clean_data['response'].str.lower()
clean_data['response'] = clean_data['response'].str.replace('[^a-z]+', ' ')
clean_data['response'] = clean_data['response'].str.findall('\w{3,}').str.join(' ')
# Out:
# <ipython-input-9-31eaec941292>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   clean_data['response'] = clean_data['response'].str.replace('[^a-z]+', ' ')

# %%
clean_data = clean_data[clean_data['response'] != '-99']

# %% [markdown]
# from sklearn.feature_extraction.text import TfidfVectorizer
#
#
# documents =clean_data['response'].values.astype("U")
#
#
#
# vectorizer = TfidfVectorizer(stop_words = ('english'))
# features = vectorizer.fit_transform(documents)

# %% [markdown]
# df_4 = pd.DataFrame(lens)

# %%
clean_data.shape
# Out:
# (55202, 4)

# %%
import string
clean_data["response"] = [char for char in clean_data["response"]]

# %%
df1 = pd.merge(df_1, clean_data, left_index=True, right_index=True)

# %% [markdown]
# df2 = pd.merge(df_1, df1, left_on='ID', right_on='F')

# %%
df1.head()
# Out:
#    ID  Live_Alone groupedmaritalstatus Lonelycategrical  \
# 0  29           1                 1.00             1.00
# 1  32           1                 1.00             2.00
# 2  33         -99                    0                0
# 3  34           1                 1.00             1.00
# 4  35         -99                    0                0
#
#   positivelonelinessgrouped groupedtimealone groupedhealth   F  gender   age  \
# 0                         0             2.00          1.00  29     1.0  89.0
# 1                      1.00             2.00          1.00  30     2.0  44.0
# 2                         0                0             0  31     NaN   NaN
# 3                      2.00             1.00          2.00  32     2.0  63.0
# 4                         0                0             0  33     NaN   NaN
#
#                                             response
# 0  time reflect close family affairs time reflect...
# 1
# 2
# 3         not fitting sad distant emotionally others
# 4

# %%
df1.dtypes
# Out:
# ID                             int64
# Live_Alone                     int64
# groupedmaritalstatus          object
# Lonelycategrical              object
# positivelonelinessgrouped     object
# groupedtimealone              object
# groupedhealth                 object
# F                              int64
# gender                       float64
# age                          float64
# response                      object
# dtype: object

# %%
df_sel = df1[["ID","groupedmaritalstatus","Live_Alone", "Lonelycategrical", "response"]]

# %%
df_sel
# Out:
#           ID groupedmaritalstatus  Live_Alone Lonelycategrical  \
# 0         29                 1.00           1             1.00
# 1         32                 1.00           1             2.00
# 2         33                    0         -99                0
# 3         34                 1.00           1             1.00
# 4         35                    0         -99                0
# ...      ...                  ...         ...              ...
# 55055  55227                    0         -99                0
# 55056  55228                    0         -99                0
# 55057  55229                    0         -99                0
# 55058  55230                    0         -99                0
# 55059  55231                    0         -99                0
#
#                                                 response
# 0      time reflect close family affairs time reflect...
# 1
# 2
# 3             not fitting sad distant emotionally others
# 4
# ...                                                  ...
# 55055
# 55056
# 55057
# 55058
# 55059
#
# [55059 rows x 5 columns]

# %%
Not_lonely = df_sel[df_sel.Lonelycategrical == '1.00']
Lonely = df_sel[df_sel.Lonelycategrical == '2.00']

# %%
len(Not_lonely), len(Lonely)
# Out:
# (29778, 14847)

# %%
Not_lonely
# Out:
#           ID groupedmaritalstatus  Live_Alone Lonelycategrical  \
# 0         29                 1.00           1             1.00
# 3         34                 1.00           1             1.00
# 5         36                 1.00           1             1.00
# 7         38                 1.00           1             1.00
# 11        42                 2.00           1             1.00
# ...      ...                  ...         ...              ...
# 46698  46870                 2.00           1             1.00
# 46732  46904                 2.00           2             1.00
# 46738  46910                 1.00           1             1.00
# 46937  47109                 2.00           2             1.00
# 46938  47110                 1.00           1             1.00
#
#                                                 response
# 0      time reflect close family affairs time reflect...
# 3             not fitting sad distant emotionally others
# 5
# 7            feeling like one turn rely having one speak
# 11
# ...                                                  ...
# 46698  not knowing turn times wanting share news worr...
# 46732
# 46738  void being surrounded people able reach anyone...
# 46937         lack meaningful relationships unhappy self
# 46938                      feeling one share things with
#
# [29778 rows x 5 columns]

# %%
y = np.array(Not_lonely.ID)
y2 = np.array(Lonely.ID)
# print("SAMPLE",X[0])
# print("SHAPE",X.shape)
# print("TARGET",target_names[y[0]])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer


documents1 = Not_lonely.response.values.astype("U")


documents2 =Lonely.response.values.astype("U")

vectorizer = TfidfVectorizer(stop_words = ('english'))
features1 = vectorizer.fit_transform(documents1)

features2 = vectorizer.fit_transform(documents2)

# %%
len_01 = TruncatedSVD(n_components=100, n_iter=7,  random_state=42).fit_transform(features1)

len_02 = TruncatedSVD(n_components=100, n_iter=7,  random_state=42).fit_transform(features2)

# %%
len_01
# Out:
# array([[ 0.07791695,  0.02512752,  0.04134036, ...,  0.01122397,
#         -0.00154872,  0.01117866],
#        [ 0.04115481, -0.02065667, -0.00444314, ..., -0.02624912,
#          0.04375944, -0.02284042],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 0.12700216,  0.03105304,  0.12012101, ..., -0.0119594 ,
#          0.06698869, -0.14352616],
#        [ 0.05638109,  0.00845233,  0.06136547, ...,  0.09403661,
#         -0.02909447, -0.03996737],
#        [ 0.49585872,  0.20662136, -0.29853074, ...,  0.00544567,
#          0.00610024,  0.00114788]])

# %%
import umap
import numpy as np
lens1 = umap.UMAP(n_components=2,
                  random_state=1).fit_transform(len_01)

lens2 = umap.UMAP(n_components=2,
                  random_state=1).fit_transform(len_02)

# %%
lens1
# Out:
# array([[ 9.816795 ,  2.5079584],
#        [ 8.44135  ,  8.259495 ],
#        [20.804237 , -3.0941594],
#        ...,
#        [ 7.8546667,  1.0590951],
#        [11.637902 ,  5.0954685],
#        [ 5.83529  ,  4.6289363]], dtype=float32)

# %%
import kmapper as km
from kmapper import Cover, jupyter
import numpy as np

from sklearn.datasets import fetch_20newsgroups
from sklearn.cluster import AgglomerativeClustering
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import Isomap
from sklearn.preprocessing import MinMaxScaler

# %%
mapper = km.KeplerMapper(verbose=2)

projected_X1 = mapper.fit_transform(len_01, lens1)

projected_X2 = mapper.fit_transform(len_02, lens2)
# Out:
# KeplerMapper(verbose=2)
# ..Composing projection pipeline of length 1:
# 	Projections: [[ 9.816795   2.5079584]
#  [ 8.44135    8.259495 ]
#  [20.804237  -3.0941594]
#  ...
#  [ 7.8546667  1.0590951]
#  [11.637902   5.0954685]
#  [ 5.83529    4.6289363]]
# 	Distance matrices: False
# 	Scalers: MinMaxScaler()
# ..Projecting on data shaped (29778, 100)
#
# ..Scaling with: MinMaxScaler()
#
# ..Composing projection pipeline of length 1:
# 	Projections: [[20.470552  -9.860391 ]
#  [20.197037  -7.860808 ]
#  [ 8.758516   3.5188074]
#  ...
#  [ 8.891176  -3.7037034]
#  [20.551163  -9.069796 ]
#  [13.116761   0.7979433]]
# 	Distance matrices: False
# 	Scalers: MinMaxScaler()
# ..Projecting on data shaped (14847, 100)
#
# ..Scaling with: MinMaxScaler()

# %%
import sklearn

graph1 = mapper.map(
    lens1, 
    clusterer=sklearn.cluster.DBSCAN(eps=0.3, min_samples=15),
    cover=km.Cover(20, 0.2),
)

graph2 = mapper.map(
    lens2, 
    clusterer=sklearn.cluster.DBSCAN(eps=0.3, min_samples=15),
    cover=km.Cover(20, 0.2),
)
# Out:
# Mapping on data shaped (29778, 2) using lens shaped (29778, 2)
#
# Minimal points in hypercube before clustering: 15
# Creating 400 hypercubes.
#    > Found 1 clusters in hypercube 0.
#    > Found 1 clusters in hypercube 1.
#    > Found 1 clusters in hypercube 2.
#    > Found 1 clusters in hypercube 3.
#    > Found 1 clusters in hypercube 4.
#    > Found 1 clusters in hypercube 5.
#    > Found 1 clusters in hypercube 6.
#    > Found 1 clusters in hypercube 7.
#    > Found 1 clusters in hypercube 8.
# Cube_9 is empty.
#
#    > Found 1 clusters in hypercube 10.
# Cube_11 is empty.
#
# Cube_12 is empty.
#
#    > Found 2 clusters in hypercube 13.
#    > Found 2 clusters in hypercube 14.
#    > Found 1 clusters in hypercube 15.
# Cube_16 is empty.
#
# Cube_17 is empty.
#
# Cube_18 is empty.
#
#    > Found 1 clusters in hypercube 19.
#    > Found 2 clusters in hypercube 20.
#    > Found 1 clusters in hypercube 21.
#    > Found 1 clusters in hypercube 22.
#    > Found 1 clusters in hypercube 23.
#    > Found 1 clusters in hypercube 24.
#    > Found 2 clusters in hypercube 25.
#    > Found 2 clusters in hypercube 26.
#    > Found 1 clusters in hypercube 27.
#    > Found 1 clusters in hypercube 28.
#    > Found 1 clusters in hypercube 29.
#    > Found 1 clusters in hypercube 30.
#    > Found 1 clusters in hypercube 31.
#    > Found 1 clusters in hypercube 32.
#    > Found 2 clusters in hypercube 33.
# Cube_34 is empty.
#
# Cube_35 is empty.
#
# Cube_36 is empty.
#
#    > Found 1 clusters in hypercube 37.
# Cube_38 is empty.
#
#    > Found 1 clusters in hypercube 39.
#    > Found 1 clusters in hypercube 40.
#    > Found 1 clusters in hypercube 41.
#    > Found 1 clusters in hypercube 42.
#    > Found 1 clusters in hypercube 43.
#    > Found 1 clusters in hypercube 44.
#    > Found 2 clusters in hypercube 45.
#    > Found 2 clusters in hypercube 46.
#    > Found 1 clusters in hypercube 47.
#    > Found 1 clusters in hypercube 48.
#    > Found 1 clusters in hypercube 49.
# Cube_50 is empty.
#
#    > Found 1 clusters in hypercube 51.
#    > Found 2 clusters in hypercube 52.
#    > Found 1 clusters in hypercube 53.
#    > Found 1 clusters in hypercube 54.
#    > Found 1 clusters in hypercube 55.
#    > Found 1 clusters in hypercube 56.
#    > Found 1 clusters in hypercube 57.
#    > Found 2 clusters in hypercube 58.
#    > Found 2 clusters in hypercube 59.
#    > Found 1 clusters in hypercube 60.
#    > Found 1 clusters in hypercube 61.
#    > Found 1 clusters in hypercube 62.
#    > Found 1 clusters in hypercube 63.
# Cube_64 is empty.
#
#    > Found 1 clusters in hypercube 65.
#    > Found 3 clusters in hypercube 66.
#    > Found 3 clusters in hypercube 67.
#    > Found 2 clusters in hypercube 68.
#    > Found 1 clusters in hypercube 69.
#    > Found 1 clusters in hypercube 70.
#    > Found 1 clusters in hypercube 71.
#    > Found 2 clusters in hypercube 72.
#    > Found 3 clusters in hypercube 73.
#    > Found 2 clusters in hypercube 74.
#    > Found 1 clusters in hypercube 75.
#    > Found 2 clusters in hypercube 76.
#    > Found 2 clusters in hypercube 77.
#    > Found 1 clusters in hypercube 78.
#    > Found 3 clusters in hypercube 79.
#    > Found 2 clusters in hypercube 80.
# Cube_81 is empty.
#
#    > Found 1 clusters in hypercube 82.
#    > Found 1 clusters in hypercube 83.
#    > Found 1 clusters in hypercube 84.
#    > Found 1 clusters in hypercube 85.
# Cube_86 is empty.
#
# Cube_87 is empty.
#
# Cube_88 is empty.
#
#    > Found 0 clusters in hypercube 89.
#    > Found 1 clusters in hypercube 90.
#    > Found 1 clusters in hypercube 91.
#    > Found 1 clusters in hypercube 92.
#    > Found 1 clusters in hypercube 93.
#    > Found 1 clusters in hypercube 94.
# Cube_95 is empty.
#
#    > Found 1 clusters in hypercube 96.
#    > Found 1 clusters in hypercube 97.
#    > Found 1 clusters in hypercube 98.
#    > Found 1 clusters in hypercube 99.
#    > Found 1 clusters in hypercube 100.
#    > Found 1 clusters in hypercube 101.
#    > Found 1 clusters in hypercube 102.
#    > Found 1 clusters in hypercube 103.
#
# Created 168 edges and 111 nodes in 0:00:01.210964.
# Mapping on data shaped (14847, 2) using lens shaped (14847, 2)
#
# Minimal points in hypercube before clustering: 15
# Creating 400 hypercubes.
#    > Found 1 clusters in hypercube 0.
#    > Found 1 clusters in hypercube 1.
# Cube_2 is empty.
#
# Cube_3 is empty.
#
# Cube_4 is empty.
#
#    > Found 1 clusters in hypercube 5.
#    > Found 1 clusters in hypercube 6.
#    > Found 2 clusters in hypercube 7.
#    > Found 1 clusters in hypercube 8.
#    > Found 1 clusters in hypercube 9.
#    > Found 4 clusters in hypercube 10.
#    > Found 2 clusters in hypercube 11.
#    > Found 0 clusters in hypercube 12.
#    > Found 1 clusters in hypercube 13.
#    > Found 2 clusters in hypercube 14.
#    > Found 1 clusters in hypercube 15.
#    > Found 1 clusters in hypercube 16.
#    > Found 1 clusters in hypercube 17.
#    > Found 2 clusters in hypercube 18.
#    > Found 3 clusters in hypercube 19.
#    > Found 2 clusters in hypercube 20.
#    > Found 1 clusters in hypercube 21.
#    > Found 2 clusters in hypercube 22.
#    > Found 1 clusters in hypercube 23.
#    > Found 1 clusters in hypercube 24.
#    > Found 1 clusters in hypercube 25.
#    > Found 1 clusters in hypercube 26.
#    > Found 1 clusters in hypercube 27.
#    > Found 1 clusters in hypercube 28.
#    > Found 3 clusters in hypercube 29.
#    > Found 1 clusters in hypercube 30.
#    > Found 1 clusters in hypercube 31.
# Cube_32 is empty.
#
#    > Found 1 clusters in hypercube 33.
# Cube_34 is empty.
#
#    > Found 1 clusters in hypercube 35.
#    > Found 1 clusters in hypercube 36.
#    > Found 1 clusters in hypercube 37.
#    > Found 1 clusters in hypercube 38.
#    > Found 1 clusters in hypercube 39.
#    > Found 1 clusters in hypercube 40.
#    > Found 3 clusters in hypercube 41.
#    > Found 1 clusters in hypercube 42.
# Cube_43 is empty.
#
#    > Found 1 clusters in hypercube 44.
#    > Found 1 clusters in hypercube 45.
#    > Found 1 clusters in hypercube 46.
#    > Found 1 clusters in hypercube 47.
#    > Found 1 clusters in hypercube 48.
#    > Found 1 clusters in hypercube 49.
#    > Found 1 clusters in hypercube 50.
#    > Found 2 clusters in hypercube 51.
# Cube_52 is empty.
#
# Cube_53 is empty.
#
#    > Found 1 clusters in hypercube 54.
#    > Found 2 clusters in hypercube 55.
#    > Found 1 clusters in hypercube 56.
#    > Found 2 clusters in hypercube 57.
#    > Found 2 clusters in hypercube 58.
# Cube_59 is empty.
#
# Cube_60 is empty.
#
#    > Found 1 clusters in hypercube 61.
# Cube_62 is empty.
#
# Cube_63 is empty.
#
# Cube_64 is empty.
#
#    > Found 1 clusters in hypercube 65.
#    > Found 1 clusters in hypercube 66.
#    > Found 1 clusters in hypercube 67.
#    > Found 1 clusters in hypercube 68.
#    > Found 1 clusters in hypercube 69.
# Cube_70 is empty.
#
#    > Found 1 clusters in hypercube 71.
#    > Found 1 clusters in hypercube 72.
#    > Found 1 clusters in hypercube 73.
#    > Found 1 clusters in hypercube 74.
#    > Found 1 clusters in hypercube 75.
#    > Found 1 clusters in hypercube 76.
#
# Created 139 edges and 81 nodes in 0:00:00.529578.

# %% [markdown]
# !pip install ripser umap-learn kmapper persim PersistenceImages
# !pip install git+https://github.com/shizuo-kaji/CubicalRipser_3dim
# !pip install tomaster Boruta
# !pip install gudhi

# %% [markdown]
# !pip install python-igraph plotly ipywidgets

# %% [markdown]
# from sklearn.manifold import Isomap
# X1 = Isomap(n_components=50, n_jobs=-1).fit_transform(features)

# %% [markdown]
# mapper = km.KeplerMapper(verbose=2)
#
# projected_X = mapper.fit_transform(X,
#     projection=[TfidfVectorizer(analyzer="char",
#                                 ngram_range=(1,6),
#                                 max_df=0.83,
#                                 min_df=0.05),
#                 TruncatedSVD(n_components=100,
#                              random_state=1729),
#                 Isomap(n_components=2,
#                        n_jobs=-1)],
#     scaler=[None, None, MinMaxScaler()])
#
# print("SHAPE",projected_X.shape)

# %%
import matplotlib.pyplot as plt
import numpy as np
import sklearn
from sklearn import datasets
from sklearn.preprocessing import MinMaxScaler
import kmapper as km

# %%
    
    
mapper.visualize(
    graph1,
    path_html="Project0/Mapper_Not_Lonely1.html",
    title="Not_lonely",
    custom_tooltips=y,
    color_values=lens1,
    color_function_name=["lens_01", "lens1"],
    node_color_function=["mean", "std", "median", "max"],
)
# Out:
# Wrote visualization to: Project0/Mapper_Not_Lonely1.html
# '<!DOCTYPE html>\n<html>\n\n<head>\n  <meta charset="utf-8">\n  <meta name="generator" content="KeplerMapper">\n  <title>Not_lonely | KeplerMapper</title>\n\n  <link rel="icon" type="image/png" href="http://i.imgur.com/axOG6GJ.jpg" />\n\n  <link href=\'https://fonts.googleapis.com/css?family=Roboto+Mono:700,300\' rel=\'stylesheet\' type=\'text/css\'>\n  <style>* {\n  margin: 0;\n  padding: 0;\n}\n\nhtml, body {\n  height: 100%;\n}\n\nbody {\n  font-family: "Roboto Mono", "Helvetica", sans-serif;\n  font-size: 14px;\n}\n\n#logo {\n  width:  85px;\n  height: 85px;\n}\n\n#display {\n  color: #95A5A6;\n  background: #212121;\n}\n\n#header {\n  background: #111111;\n}\n\n#print {\n  color: #000;\n  background: #FFF;\n}\n\nh1 {\n  font-size: 21px;\n  font-weight: 300;\n  font-weight: 300;\n}\n\nh2 {\n  font-size: 18px;\n  padding-bottom: 20px;\n  font-weight: 300;\n}\n\nh3 {\n  font-size: 14px;\n  font-weight: 700;\n  text-transform: uppercase;\n}\n\nh4 {\n  font-size: 13px;\n  font-weight: 700;\n  text-transform: uppercase;\n  padding-bottom:0px;\n}\n\n\n#meta_content h3 {\n  float: left;\n  padding-right: 8px;\n}\n\np, #tooltip_content h3, ol, ul, table {\n  padding-bottom: 10px;\n}\n\nol, ul {\n  padding-left: 20px;\n}\n\nol b {\n  display: block;\n}\n\na {\n  color: #16a085;\n  text-decoration: none;\n}\n\n.pane {\n  position: relative;\n}\n\n.pane-left {\n  float: left;\n}\n\n.pane-right {\n  float: right;\n}\n\na:hover {\n  color: #2ecc71;\n}\n\n.banner {\n  /* height: 35px; */\n  padding: 10px 0px;\n}\n\n\n#print #header {\n  background: #FFF;\n}\n\n\n#canvas {\n  width: 100%;\n}\n\n#svg {\n  position: absolute;\n}\n\n#toolbar {\n  padding-top: 5px;\n  margin-bottom: 5px;\n  width: 100%;\n}\n\n#display #toolbar {\n}\n\n#display .banner {\n  border-top: 1px solid #000;\n}\n\n.inline-block {\n  display: inline-block;\n}\n\n.tool_item {\n  padding-left: 10px;\n  padding-right: 10px;\n}\n\n.pane_content {\n  width: 300px;\n  height:100%;\n  padding: 20px;\n  overflow: auto;\n  display: none;\n}\n\n.pane {\n  z-index: 1;\n}\n\n#display .pane_content {\n  background: #191919;\n}\n\n#print .pane_content{\n  background: #FFF;\n}\n\n#meta_content::-webkit-scrollbar, #tooltip_content::-webkit-scrollbar {\n  width: 1em;\n}\n\n#meta_content::-webkit-scrollbar-track, #tooltip_content::-webkit-scrollbar-track {\n  -webkit-box-shadow: inset 0 0 6px rgba(0, 0, 0, 0.3);\n}\n\n#meta_content::-webkit-scrollbar-thumb, #tooltip_content::-webkit-scrollbar-thumb {\n  background-color: darkgrey;\n  outline: 1px solid slategrey;\n}\n\n.histogram {\n  display: block;\n  height: 100px;\n  padding-top: 50px;\n  clear: both;\n}\n\n#display .histogram {\n  opacity: 0.68;\n}\n\n.bin {\n  width: 10%;\n  float: left;\n}\n\n.bin div {\n  font-size: 10px;\n  display: block;\n  width: 35px;\n  margin-top: -30px;\n  text-align: right;\n  margin-left: -3px;\n  -webkit-transform: rotate(-90deg);\n  -moz-transform: rotate(-90deg);\n  -ms-transform: rotate(-90deg);\n  -o-transform: rotate(-90deg);\n}\n\n.histogram:hover {\n  opacity: 1.;\n}\n\n#display .circle {\n  stroke-opacity: 0.18;\n  stroke-width: 7px;\n  stroke: #000;\n}\n\n#print .circle {\n  stroke-opacity: 1;\n  stroke-width: 2px;\n  stroke: #000;\n  stroke-linecap: round;\n}\n\n#print .link {\n  stroke: #000;\n}\n\n#display .link {\n  stroke: rgba(160, 160, 160, 0.5);\n}\n\ntable {\n  border-collapse: collapse;\n  display: table;\n  width: 100%;\n  margin-bottom: 20px;\n}\n\ntd, th {\n  padding: 5px;\n  text-align: left;\n}\n\n#display th {\n  background: #212121\n}\n\ntd {\n  border-bottom: 1px solid #111;\n}\n\n.highlight {\n  filter: url(#drop-shadow-pulse);\n}\n\n.control-row {\n  padding: 5px 0px;\n}\n\n.btn {\n  display: inline-block;\n  padding: 0.35em 1.2em;\n  border: 0.1em solid #FFFFFF;\n  margin: 0 0.3em 0.3em 0;\n  border-radius: 0.12em;\n  box-sizing: border-box;\n  text-decoration: none;\n  background-color: transparent;\n  font-weight: 300;\n  color: #FFFFFF;\n  text-align: center;\n  tran ...

# %%
mapper.visualize(
    graph2,
    path_html="Project0/Mapper_Lonely1.html",
    title="Lonely",
    custom_tooltips=y2,
    color_values=lens1,
    color_function_name=["lens_01", "lens1"],
    node_color_function=["mean", "std", "median", "max"],
)
# Out:
# Wrote visualization to: Project0/Mapper_Lonely1.html
# '<!DOCTYPE html>\n<html>\n\n<head>\n  <meta charset="utf-8">\n  <meta name="generator" content="KeplerMapper">\n  <title>Lonely | KeplerMapper</title>\n\n  <link rel="icon" type="image/png" href="http://i.imgur.com/axOG6GJ.jpg" />\n\n  <link href=\'https://fonts.googleapis.com/css?family=Roboto+Mono:700,300\' rel=\'stylesheet\' type=\'text/css\'>\n  <style>* {\n  margin: 0;\n  padding: 0;\n}\n\nhtml, body {\n  height: 100%;\n}\n\nbody {\n  font-family: "Roboto Mono", "Helvetica", sans-serif;\n  font-size: 14px;\n}\n\n#logo {\n  width:  85px;\n  height: 85px;\n}\n\n#display {\n  color: #95A5A6;\n  background: #212121;\n}\n\n#header {\n  background: #111111;\n}\n\n#print {\n  color: #000;\n  background: #FFF;\n}\n\nh1 {\n  font-size: 21px;\n  font-weight: 300;\n  font-weight: 300;\n}\n\nh2 {\n  font-size: 18px;\n  padding-bottom: 20px;\n  font-weight: 300;\n}\n\nh3 {\n  font-size: 14px;\n  font-weight: 700;\n  text-transform: uppercase;\n}\n\nh4 {\n  font-size: 13px;\n  font-weight: 700;\n  text-transform: uppercase;\n  padding-bottom:0px;\n}\n\n\n#meta_content h3 {\n  float: left;\n  padding-right: 8px;\n}\n\np, #tooltip_content h3, ol, ul, table {\n  padding-bottom: 10px;\n}\n\nol, ul {\n  padding-left: 20px;\n}\n\nol b {\n  display: block;\n}\n\na {\n  color: #16a085;\n  text-decoration: none;\n}\n\n.pane {\n  position: relative;\n}\n\n.pane-left {\n  float: left;\n}\n\n.pane-right {\n  float: right;\n}\n\na:hover {\n  color: #2ecc71;\n}\n\n.banner {\n  /* height: 35px; */\n  padding: 10px 0px;\n}\n\n\n#print #header {\n  background: #FFF;\n}\n\n\n#canvas {\n  width: 100%;\n}\n\n#svg {\n  position: absolute;\n}\n\n#toolbar {\n  padding-top: 5px;\n  margin-bottom: 5px;\n  width: 100%;\n}\n\n#display #toolbar {\n}\n\n#display .banner {\n  border-top: 1px solid #000;\n}\n\n.inline-block {\n  display: inline-block;\n}\n\n.tool_item {\n  padding-left: 10px;\n  padding-right: 10px;\n}\n\n.pane_content {\n  width: 300px;\n  height:100%;\n  padding: 20px;\n  overflow: auto;\n  display: none;\n}\n\n.pane {\n  z-index: 1;\n}\n\n#display .pane_content {\n  background: #191919;\n}\n\n#print .pane_content{\n  background: #FFF;\n}\n\n#meta_content::-webkit-scrollbar, #tooltip_content::-webkit-scrollbar {\n  width: 1em;\n}\n\n#meta_content::-webkit-scrollbar-track, #tooltip_content::-webkit-scrollbar-track {\n  -webkit-box-shadow: inset 0 0 6px rgba(0, 0, 0, 0.3);\n}\n\n#meta_content::-webkit-scrollbar-thumb, #tooltip_content::-webkit-scrollbar-thumb {\n  background-color: darkgrey;\n  outline: 1px solid slategrey;\n}\n\n.histogram {\n  display: block;\n  height: 100px;\n  padding-top: 50px;\n  clear: both;\n}\n\n#display .histogram {\n  opacity: 0.68;\n}\n\n.bin {\n  width: 10%;\n  float: left;\n}\n\n.bin div {\n  font-size: 10px;\n  display: block;\n  width: 35px;\n  margin-top: -30px;\n  text-align: right;\n  margin-left: -3px;\n  -webkit-transform: rotate(-90deg);\n  -moz-transform: rotate(-90deg);\n  -ms-transform: rotate(-90deg);\n  -o-transform: rotate(-90deg);\n}\n\n.histogram:hover {\n  opacity: 1.;\n}\n\n#display .circle {\n  stroke-opacity: 0.18;\n  stroke-width: 7px;\n  stroke: #000;\n}\n\n#print .circle {\n  stroke-opacity: 1;\n  stroke-width: 2px;\n  stroke: #000;\n  stroke-linecap: round;\n}\n\n#print .link {\n  stroke: #000;\n}\n\n#display .link {\n  stroke: rgba(160, 160, 160, 0.5);\n}\n\ntable {\n  border-collapse: collapse;\n  display: table;\n  width: 100%;\n  margin-bottom: 20px;\n}\n\ntd, th {\n  padding: 5px;\n  text-align: left;\n}\n\n#display th {\n  background: #212121\n}\n\ntd {\n  border-bottom: 1px solid #111;\n}\n\n.highlight {\n  filter: url(#drop-shadow-pulse);\n}\n\n.control-row {\n  padding: 5px 0px;\n}\n\n.btn {\n  display: inline-block;\n  padding: 0.35em 1.2em;\n  border: 0.1em solid #FFFFFF;\n  margin: 0 0.3em 0.3em 0;\n  border-radius: 0.12em;\n  box-sizing: border-box;\n  text-decoration: none;\n  background-color: transparent;\n  font-weight: 300;\n  color: #FFFFFF;\n  text-align: center;\n  transiti ...

# %%
import pandas as pd
import re


list_of_values= [177, 224, 239, 312, 518, 720, 2479, 2769, 2771, 3012, 3461, 3562, 4272, 4982, 5093, 6505, 6894, 7124, 7743, 8056, 8363, 9027, 9442, 10465, 10580, 10657, 11121, 11462, 11712, 11719, 12183, 13645, 13677, 13928, 14846, 16290, 17194, 18041, 18105, 18856, 19117, 19295, 19936, 19983, 20094, 20217, 20459, 21293, 21403, 21744, 22882, 23394, 24018, 24506, 24979, 25921, 26079, 26270, 27153, 27334, 27525, 27814, 27869, 28198, 28659, 28858, 28907, 28990, 30103, 30485, 30566, 31533, 32724, 34446, 34575, 36138, 36265, 36282, 36397, 36543, 37337, 37840, 38257, 38590, 38932, 39734, 40009, 40196, 41074, 41184, 41492, 41528, 41955, 42504, 43077, 43775, 44289, 44325, 44653, 44835, 45600, 45731, 45871, 46036, 46077, 46759] 



df_21= df_2[df_2['F'].isin(list_of_values)]

df_21.values
# Out:
# array([[177, 2.0, 49.0, '-99'],
#        [224, 2.0, 70.0, '-99'],
#        [239, 2.0, 21.0, '-99'],
#        [312, 2.0, 65.0,
#         'feeling of isolation, with noone to be a ble to confide inner thoughts to'],
#        [518, 2.0, 35.0,
#         'Betrayal by the only family I had made me separate myself from them for peace of mind resulting in having no one close to me at my age. '],
#        [720, 1.0, 63.0, '-99'],
#        [2479, 2.0, 53.0,
#         'Loneliness means being alone in most of what you do in your life or sometimes being around other people but just feeling different and disconnected with them.'],
#        [2769, 1.0, 57.0, 'Unable to find someone who understants me.'],
#        [2771, 2.0, 77.0, '-99'],
#        [3012, 2.0, nan,
#         "loneliness is not solitude.  it is not being alone, it is about feeling isolated and worthless. loneliness can mean the loss of a valued connection - just because a person may speak to lots of people, it doesn't mean that there is a connection."],
#        [3461, 1.0, 62.0,
#         'Feeling misunderstood, not connected, not valued,ignored'],
#        [3562, 2.0, 67.0,
#         "Loneliness, to me, means several things. Feeling alone, without regular hugs and kisses, feeling disconnected to the world, feeling that the world is moving on and I'm on the sidelines. Feeling that I am not equal to others. Spending too much time on my own. Feeling loved. "],
#        [4272, 1.0, 38.0,
#         'True loneliness is how I�??m feeling right now since I lost my husband of 50 years last summer. I nursed him for many years and devoted my life to him, giving up my job and my friends. I have family but often feel lonelier when I�??m with them because He isn�??t there'],
#        [4982, 2.0, 58.0,
#         'It means having nobody special with whom to share the highs and lows of life. It means coming home bursting to tell someone about your day , but there�??s nobody there. It means sitting in a busy cafe looking at the couples and families all around you interacting over their pot of tea! It means waking in the middle of the night with nobody to turn to. It means being in bed with flu, desperate for someone to make you a cup of tea, but not wanting to bother your friends or risk passing on your germs.'],
#        [5093, 1.0, 43.0,
#         'Feeling alone. Not having much communication or contact in person or via social media. '],
#        [6505, 2.0, 49.0,
#         'Absence of connection to other people in a meaningful way. Not being understood and/or shunned '],
#        [6894, 1.0, 61.0,
#         'alone mentally. fear to trust. no sharing of experiences.'],
#        [7124, 2.0, 43.0,
#         "being around people but not connecting with anyone. feeling like no one really likes you but you don't know why. "],
#        [7743, 2.0, 73.0,
#         "Boredom. No one to share worries with. Distrust of others' motives. Wasting life. feelings of being abnormal. Missing out."],
#        [8056, 2.0, 71.0, 'Sad depressed '],
#        [8363, 1.0, 54.0,
#         'Feeling like no one cares or is interested in listening.'],
#        [9027, 2.0, 28.0,
#         'Loneliness is a feeling of constant emptiness and isolation, even when around people'],
#        [9442, 1.0, 71.0, 'Helplessness. No one to turn to. Isolation. '],
#        [10465, 1.0, nan,
#         'Loneliness means not having anyone to call to share happy or sad news.'],
#        [10580, 2.0, 55.0,
#         'Feeling of being disconnected, no one caring or thinking about you'],
#        [10657, 2.0, 20.0, 'Like ships that pass in the night'],
#        [11121, 2.0, 45.0, 'Feel isolated, in a bubble I cannot break.'],
#        [11462, 2.0, 41.0,
#         'Having no friends. Being completely alone. Having no one to confide in or support through good/bad times.'],
#        [11712, 2.0, 20.0,
#         'The worst part is having to cook for one and eat alone.   Being unable to go on holiday as most companies base holiday prices on two persons.  A general feeling of being left out of things.'],
#        [11719, 1.0, 53.0,
#         'No one relates with me leading to no empathy and  seemingly endless misunderstang.  My relationships seem to devolve into rivalry.  Economic and lifestyle comparesens that tend to engender jealousy. '],
#        [12183, 2.0, 70.0,
#         'Lonliness is consistently feeling that there another person who would be receptive to spending time with me.'],
#        [13645, 1.0, 22.0,
#         "Feeling that you have noone to 'just be' with. feeling afraid of the future anf growing old. having only yourself to rely on in a crisis and feeling bored."],
#        [13677, 1.0, 19.0,
#         'a bad condition and one that is only experienced by people who are unworthy of relationships'],
#        [13928, 1.0, 51.0,
#         'Someone who feels like the odd one out. A person who people avoid. Being unwanted. Feeling unworthy.'],
#        [14846, 2.0, 48.0,
#         'Feeling of a deep disconnect with your peers or people surrounding you and inability to overcome that gap in your mind. '],
#        [16290, 1.0, 24.0,
#         "It means feeling like no-one likes me or wants to be with me. Other seem much more likeable and I wonder what is wrong with me that people don't want to be with me. "],
#        [17194, 2.0, 55.0,
#         'feeling empty and isolated from society. depressing and cold.'],
#        [18041, 1.0, 60.0,
#         'Coming home to an empty property makes me feel so sad. Looking forward to going to work so I have people to talk to. '],
#        [18105, 2.0, 46.0,
#         "Loneliness means to be surronded by people but don't feel connected with them.don't have anyone to talk to in the middle of the night.don't feel that you are important to anyone."],
#        [18856, 2.0, 67.0,
#         'Missing out. Sad. Not being able to talk to anyone. lonely. Separate. On the edge of society, looking in. Feeling unworthy. Feeling unloved. Feeling angry. Self loathing. Social anxiety due to lack of practice. Fear of doing or saying the wrong thing. Performing when meeting new people. Fear of not being good enough. '],
#        [19117, 2.0, 60.0, 'Pain.  Sadness.  Lack of value.'],
#        [19295, 2.0, 63.0,
#         "Isolation.  Nobody to share things with, to have fun with, to support each other through the good and the bad.  Going for days without talking to anyone, only the person in the local shop where I buy my paper.  Looking at other couples, people laughing and sharing, and thinking there must be something wrong with me, which is a vicious circle because all of the negative thoughts just reinforce those feelings.  Fearful of the future, when there's only me....."],
#        [19936, 2.0, 47.0,
#         'Lonliness means missing the company of someone who you can be yourself with.'],
#        [19983, 2.0, 17.0,
#         'loneliness to me is the feeling of nobody being around you both mentall and physically. '],
#        [20094, 2.0, 48.0,
#         'Feeling excluded because I am not part of a couple and have no children . Seeing others get together and go out at weekends . Having enough money to go on holiday but not wanting to go on my own and having lack of confidence to go on my own . Listening to programmes like womans hour that assume all women are in a relationship or have a family. Having noone to talk to when I need to even though I do cope on my own with running a home etc. Being scared of getting old on my own and having noone to champion me if I go into a home .'],
#        [20217, 2.0, 76.0,
#         "Loneliness means feeling isolated even in a crowded room. It can be a physical isolation in that you don't get to see people. It is not being able to communicate and confide in anyone. It is a feeling of something being missing."],
#        [20459, 3.0, 17.0, '-99'],
#        [21293, 2.0, 44.0,
#         "feeling cut off.  isolated, no-one to talk to. Unable to ask for help. Scared to brave new things. Used to being left out.  Left eveyone behindto make a better life for child and now lost courage for myself.  exhausted and reluctant to keep trying new things. Can't 'keep going to new things' so give up - a lot! difficult to put theory into practice re being loney and doing somat about it is very hard now.  no adults to just have a chat with people like me.  lost. not sure who i am now.very tearful. hiding away and pretending everythings fine when out..!"],
#        [21403, 2.0, 57.0,
#         'Not having that someone there when things get tough. Not having that one person you can trust. Not having any '],
#        [21744, 2.0, 22.0, '-99'],
#        [22882, 1.0, 32.0,
#         'A feeling of isolation even in a crowd.  Difficulty or lack of connections with others.'],
#        [23394, 2.0, 64.0,
#         "Loneliness to me is when nobody I know seems to understand me. Feels like I'm on a different page to them. Loneliness is also a result of people's nasty or negative comments that make you feel unworthy. "],
#        [24018, 2.0, 26.0,
#         "While I wouldn't mind having more friends, I feel that lack of a romantic partner contributes much more to my sense of loneliness than lack of friends."],
#        [24506, 2.0, 52.0,
#         'Emptiness. Dwelling on bad thoughts. Feeling alone, whether actually so or not. Disconnection. Feeling unique/ unrelatable.'],
#        [24979, 2.0, 35.0,
#         "To me, loneliness is wanting to be involved with people and the world, but not being able to. It may be not understanding how to get involved, not having people you want to be around, or not feeling understood or welcomed by the people around you. The idea of 'feeling lonely in a crowded room' is a very familiar one to me."],
#        [25921, 2.0, 62.0,
#         "Although I am outwardly confident, I have great circles of friends, I am married with children, I get lonely. I moved to the UK 34 yrs ago from a big Irish family. I love living in the UK but my sense of 'belonging' is sometimes what makes me feel lonely. I have a need to be around people. My mum was 1 of 9 children and my Dad was 1 of 3. I have always been surrounded by people. My husbands mum was an only child with few cousins. His dad had step-siblings. The connections between them are polar opposite to my Irish family connections. I love my own space and being an individual but the loneliness comes from that feeling of being surrounded by love and happiness in a big family. "],
#        [26079, 1.0, 37.0, 'Feeling isolated and separate from society'],
#        [26270, 2.0, 53.0,
#         'Loneliness is a feeling of despair one has when no one shows love and affection.'],
#        [27153, 1.0, 75.0,
#         'No one to share the deeper things or sadder things with'],
#        [27334, 1.0, 50.0,
#         'Not having someone you can talk to about your troubles , when you dont want to worry your family .'],
#        [27525, 1.0, 17.0, '-99'],
#        [27814, 2.0, 34.0,
#         "Loneliness seems to be a feeling of disconnectedness with most other people. It's not always that you don't talk to anyone, or are physically barred from them in any way; you just don't connect with them on an intimate, emotional level. The resulting self-doubt and feelings of undesirability only exacerbates issues, prompting the sufferer to cut themselves off, leading to a deeper malaise and feelings of general wretchedness. "],
#        [27869, 1.0, 48.0,
#         "It means feeling isolated.  It means feeling like you are not really part of or valued by society. It means not feeling heard or feeling ae if you have  value voice. It means feeling like you don't fit in anyway so don't bother trying to get involved. It means capitalist values which outweigh human values. "],
#        [28198, 2.0, 24.0, 'Not having anyone to just go do stuff with. '],
#        [28659, 2.0, 66.0,
#         'Being alone. No one to share my thoughts with. No one to ask questions. No one to have discussions with. Isolated from the rest of the world.'],
#        [28858, 2.0, 21.0,
#         'Feeling like there�??s no one you can properly talk to in bad times. Feeling like you spend too much time alone.'],
#        [28907, 1.0, 37.0,
#         "Feeling empty even when family and friend's are tnere. Just an empty space "],
#        [28990, 2.0, 52.0,
#         'Loneliness for me is exemplified by not being understood by others, friends or colleagues. Loneliness is not being able to sleep or influence negative thoughts. '],
#        [30103, 1.0, 58.0, '-99'],
#        [30485, 2.0, 40.0,
#         "Firstly, because I'll carry on typing for far too long I'd like to be brief to answer this, loneliness means very negative things to me: Increasing depression. Feelings of being bereft. Abandonment. Loss of being a popular friend. Feelings of being unwanted by society and personally. Isolation. Although I could do anything I liked (such as bike, or walking...) there was no one to invite as company even if I wanted to invite a nice friend. No laughter, no fun, there's only so much you can take being alone. No memory making. Falling out of touch with society, or so it seems, even though I like politics and always keep abreast of it, for example. No conversations. Dying alone and not being found indoors. Unhappiness long term, it's hard to make friends.. Giving up on people because 'no one cares anyway'. No being able to talk to someone who's genuinely interested. Abandonment. Abandonment. No one cares, and why should they, I could make them care, they might like me, confusion. How did I end up like this? How can I make things better? Anger and bitterness. Helplessness. Wanting to live, but no one knows. How did this happen, I used to be ok. Solitude that is very unwanted. Not having a life.I must not be a likable person. Why should *horrible bully I once knew* have what she's got she doesn't deserve it. Resentment.Gross anger at abandonment, and I hope they feel like me one day. It's not about being independent or not, you can be independent that's easy, it's about friends and knowing a person/people for a long time and sharing your life. someone/persons you can call on and they like to hear from you, as I would do them; genuine affection. pretending to feel alright, if you need to talk to someone about you MOT for example, when you do not, you feel weak and mentally exhausted from being alone. I must seem weird, to 'them'. unfairly judged. left out of conversations. seeing no one on days off, no one to engage with. I used to be happy and laugh with friends, not anymore, that was years ago; mourning this It goes on like this, so I'll finish up, thanks for reading."],
#        [30566, 2.0, 43.0,
#         "Loneliness means that you are isolated from others even though they don't realise this. It means you spend most of your tima alone and this often hurts and/or limits what you do."],
#        [31533, 2.0, 58.0,
#         'No one to talk to. No one to ring up. No one to meet for a coffee. Only Aquaintances.'],
#        [32724, 2.0, 41.0,
#         ' no one to share ideas, fun, laughter, tears or communicate with.'],
#        [34446, 2.0, 78.0,
#         'Not having congenial people within easy reach who will sometimes ask to see me.'],
#        [34575, 2.0, 68.0,
#         'I am lonely because I literally do not have any friends and I am estranged from my family because they are abusive snd do not care about me. I am truly alone in the world. In a hospital or GP surgery I do not have anyone to put down as my next of kin, because I do not have any kin.'],
#        [36138, 2.0, 70.0, '-99'],
#        [36265, 2.0, 45.0,
#         'No-one to talk to. No-one to go to social events with. No-one to share with and exchange ideas.'],
#        [36282, 1.0, 50.0, 'Depression. Prefer to be alone'],
#        [36397, 2.0, 55.0,
#         'Loneliness means: not having someone you can trust with your inner thoughts, not having anyone to socialise with, not having someone to bounce ideas off. All of which lead to a greater feeling of social anxiety, frustration, emptiness, and low self-esteem.'],
#        [36543, 2.0, 65.0,
#         'Isolation. Silence. Emptyness. Frustration. Sorrow. Peace. '],
#        [37337, 2.0, 63.0,
#         'Not being able to travel- ahd share good experiences.'],
#        [37840, 1.0, 69.0,
#         "Not having anyone to talk to. Not having anyone to just spend time with and enjoy things together. Being left behind by others who have got married and/or had kids. Not having anyone who chooses to spend time with you (not including parents amd siblings as they didn't choose you). "],
#        [38257, 1.0, 61.0,
#         'Perpetual silence. Not hearing your own voice for days because of a lack of having people to speak with. Missing home.'],
#        [38590, 2.0, 65.0,
#         'Loneliness means being disconnected from the world that surrounds me and having no one to share my thoughts with.'],
#        [38932, 2.0, 53.0,
#         'Being alone, not in a physical sense, but with your own thoughts and not wanting to share those thoughts with others (whatever the reason). It could also mean being alone physically, not that is not a pre requisite.'],
#        [39734, 1.0, 19.0,
#         'Having nobody to talk to. Acting all the time. Little to look forward to. Feeling of isolation. '],
#        [40009, 1.0, 59.0, '-99'],
#        [40196, 2.0, 36.0, 'Life.'],
#        [41074, 1.0, 30.0, 'Exclusion'],
#        [41184, 2.0, 55.0,
#         'feeling alone with my thoughts. I have always felt I am on my own in life. I have always wanted people to be close to me.'],
#        [41492, 2.0, 27.0,
#         "Loneliness - when there is nobody you could or want to share you feelings, fears, problems. It's a feeling that the people that are around would not understand what you are going through, you can not relate to their experience. "],
#        [41528, 2.0, 55.0, '-99'],
#        [41955, 2.0, 52.0, 'Feeling alienated in a group'],
#        [42504, 2.0, 16.0,
#         'Not having anyone to share things with , having to do everything , go everywhere alone , feeling an outsider , it is a horrible  frightening sinking sensation deep inside when thinking about the future, '],
#        [43077, 2.0, 33.0,
#         "Sadness about being alone. A strong desire to seek the company of others. Feeling less worthy than other people because my friends don't contact me as often as I'd like to."],
#        [43775, 2.0, 50.0,
#         'Loneliness to me means you can be surrounded by family, work collegues, friends but have an ache inside which never leaves but you can push it to one side to keep going.'],
#        [44289, 2.0, 25.0,
#         "Not being able to communicate or reach out to anyone. A sense of isolation. It's not something you choose but something that happens to you. When you're lonely you want to be around other people, connect with other people but either can't or are not doing so."],
#        [44325, 2.0, 34.0,
#         "when reality doesn't live up to expectations. not having that one person to share joys/sorrows with"],
#        [44653, 1.0, 61.0,
#         'Feeling isolated from society.  Self esteem very low (no one cares about me as something wrong with me).  As I have become older at times embrace loneliness, to be on my own, but hours not days..'],
#        [44835, 2.0, 71.0, '-99'],
#        [45600, 2.0, 36.0,
#         "It's like not having something you know you should have"],
#        [45731, 1.0, 44.0,
#         "Being alone often accomplishing life's goals, projects and activities of leisure by yourself."],
#        [45871, 2.0, 65.0,
#         'Feeling isolated. No one calling or picking up the phone to see how you are, or sharing something with. No one to meet to share a coffe and chat.'],
#        [46036, 1.0, 53.0, '-99'],
#        [46077, 1.0, 30.0,
#         "Loneliness to me means feeling lost, feeling like there's no way out of this sadness, feeling like your presence doesn't matter or affect anything or anyone, feeling like you wanna cry in someone's shoulders but you ain't got noone to do it."],
#        [46759, 1.0, 52.0, 'Boredom quietness ']], dtype=object)

# %%
list_of_value=[64,163,303,362,430,435,459,464,510,515,520,545,550,590,744,772,871,959,997] # Lonely

df_21= df_2[df_2['F'].isin(list_of_value)]

df_21.values
# Out:
# array([[64, 1.0, 32.0, '-99'],
#        [163, 1.0, 60.0,
#         'Having no-one to turn to at 4 in the afternoon or 4 in the morning. '],
#        [303, 1.0, 53.0,
#         'Feeling that you have nobody to speak to honestly who listens. Feeling alone even if you are surrounded by people.'],
#        [362, 2.0, 66.0,
#         'saddness.hoplesness.cold.disconnected.alien.void'],
#        [430, 2.0, 31.0,
#         'It means being or feeling alone. Like I currently am.'],
#        [435, 2.0, 61.0, 'No one caring if I live or die.'],
#        [459, 2.0, 70.0,
#         'Feeling alone no one to understand me. This feel worst in a crowd of people .  Isolation. Sadness. Unhappyiness. Withdrawn going into myself'],
#        [464, 2.0, 32.0, '-99'],
#        [510, 2.0, 30.0,
#         'Having severe mental health conditions makes me feel different to everyone and that no one out of the hospital environment understands. It is feeling like I will be rejected when people find out about my past. It�??s sitting at home seeing old school mates living their lives on social media and feeling like I�??m not one of them anymore. '],
#        [515, 1.0, 63.0,
#         'Isolation.  loneliness.  deep unhappiness.  loss.  Lacks of purpose or real meaning in my life.'],
#        [520, 1.0, 70.0, '-99'],
#        [545, 2.0, 16.0,
#         'Not speaking to anyone for days. Being out with someone and they just sit in there phone. Feeling like I am unwanted. Feeling like no one cares for you. You could be out with friends and family and feel physically sick cause you just do not feel like you are apart of the group. You message your partner and he does not ever reply. '],
#        [550, 2.0, 56.0, 'somebody that wants to spend time with me'],
#        [590, 2.0, 24.0,
#         'I have friends but no best friend, no-one I could confide in. Nor do I have any family, I have no parents, siblings or children. I feel isolated'],
#        [744, 1.0, 23.0, '-99'],
#        [772, 2.0, 49.0,
#         'Unwanted isolation. Emotionally crippling. A deep lain in the soul.'],
#        [871, 1.0, 70.0,
#         'sadness; missing someone who has died; lack of motivation to move on'],
#        [959, 4.0, 35.0,
#         'I have good friends but they all live elsewhere. I used to work and live in close quarters on ships and made many good friends, now that I don�??t do that I�??m mostly alone. I see my friends every few months as they pass through London. I don�??t have people I can pop in to visit or just hang out with or discuss life with or laugh with regularly.'],
#        [997, 2.0, nan,
#         'Not being listened to. Not feeling valued. Isolation. Passivity.  Unhappy without company.']],
#       dtype=object)

# %%
list_of_valu = [44,68,92,105,171,238,287,307,526,574,577,618,647,819,843,892, 1019,1039,1050,1099,1121,1166,1168,1179,1186,1223,1273,1310,1392,1425,1550,1583,1620,1644,1675,1686,1698,1717] # Not lonely


df_21= df_2[df_2['F'].isin(list_of_valu)]

df_21.values
# Out:
# array([[44, 1.0, 32.0, 'Feelimg isolated'],
#        [68, 2.0, 24.0,
#         'Wanting company or companionship, but not being able to get any.'],
#        [92, 1.0, 51.0,
#         'Loneliness is feeling like you are not in the thoughts of others. It is feeling isolated with your feelings. It is having many acquaintances and colleagues but few confidants. '],
#        [105, 1.0, 61.0, '-99'],
#        [171, nan, nan,
#         'I think loneliness is something you can do something about yourself.  Lots of people confuse loneliness with boredom.  Noone who is really busy, even if completely alone, feels lonely.'],
#        [238, 2.0, 26.0,
#         'Feeling isolated, not being able to talk to people around me.'],
#        [287, 2.0, 48.0,
#         'No one interested in me. Days on end not seeing anyone.'],
#        [307, 2.0, 51.0,
#         "Feeling empty. No one to talk to who 'understands'. "],
#        [526, 2.0, 57.0,
#         'Not seeing people in person. Not knowing  someone  who has empathy with me. Not seeing friends and family for long periods of time. Having no body to talk to about personal problems. '],
#        [574, 2.0, nan, 'Sad.no-one to talk with.no welcome home'],
#        [577, 1.0, 38.0,
#         'No one to share the little things of life with. Being desperate to talk but not having someone to call.'],
#        [618, 1.0, 66.0,
#         "Not having anyone to share with, or bounce ideas off. Being isolated when I don't want to be."],
#        [647, 2.0, 42.0, '-99'],
#        [819, 1.0, 66.0, '-99'],
#        [843, 2.0, 28.0, 'Sad. Depressed. Rejected. Dull. '],
#        [892, 2.0, 35.0,
#         "Feeling like you can't reach out to anyone, even if people are around. "],
#        [1019, 1.0, 20.0,
#         'It makes me sad. Sometimes I am lonely when I have nothing to do.'],
#        [1039, 2.0, 53.0, '-99'],
#        [1050, 2.0, 49.0,
#         'Loneliness can creep up on you and you find yourself experiencing something and needing a reassuring voice/hug or just someone to listen to your concerns when you have no one to go to '],
#        [1099, nan, nan,
#         'To me, it means feeling utterly alone and apart from everyone. '],
#        [1121, 1.0, 66.0,
#         'Feeling bored and unconnected, not able to feel common ground/understanding with those around me. Feeling as if no one wants to spend time with me.  Feeling isolated.'],
#        [1166, 2.0, 55.0, '-99'],
#        [1168, 2.0, 65.0,
#         "Loneliness is a feeling of emptiness, of living in your own 'bubble'."],
#        [1179, 2.0, 65.0,
#         'Loneliness means to me that you can be in a crowded train station, say London Euston, and still feel disconnected.'],
#        [1186, 1.0, 37.0,
#         'Feeling alone with your thought and feelings, being alone when you would rather be with company'],
#        [1223, 1.0, 27.0,
#         'psychological loneliness means sadness, pain, rejection, lack of love and affection and closeness. physical loneliness can be exhilarating when away from everyone in nature.'],
#        [1273, 1.0, 63.0,
#         'unable to settle. isolated. frustrated. often on the verge of tears. carrying a heavy heart.'],
#        [1310, 1.0, 55.0,
#         "Loneliness is the feeling of being different. I'm lonely because I am more motivated, more driven, more passionate, and more successful than my friends are. I'm lonely because only 2 people respond to my texts when I need them. Loneliness is increased by stress and by not having time to do what I need to do. "],
#        [1392, 2.0, 73.0,
#         "Mostly a good thing, I likebeing alone. But sometimes I can feel lonely when I'm excluded from things, but that's usually due to my own insecurities and unwillingness to participate in things. "],
#        [1425, 2.0, 48.0, 'okay'],
#        [1550, 2.0, 47.0,
#         'Loneliness is lacking the drive or desire to seek company, or when company lacks the drive or desire to seek you.'],
#        [1583, 1.0, 45.0,
#         "Lonliness is when I don't get a break from work or children and I don't get any time to do anything for me. I feel lonely when I don't see any of my friends socially.  I"],
#        [1620, 4.0, 60.0,
#         'A sense of being disconnected from other people.  A sense of being isoldated from things which others are enjoying.'],
#        [1644, 1.0, 48.0,
#         'No one to confide in. No one to understand me. '],
#        [1675, 2.0, 64.0, 'Disconnected and irrelevant I suppose'],
#        [1686, 1.0, 56.0,
#         'Feeling isolated from peers. Being with others but still feeling alone'],
#        [1698, 2.0, 37.0, '-99'],
#        [1717, 2.0, 47.0, '-99']], dtype=object)

# %%
list_of_valu1=[3155, 3274, 8449, 9741, 11048, 12303, 14976, 16725, 18687, 21070, 21375, 23939, 26013, 26585, 28574, 30375, 31503, 31894, 32023, 32674, 33081, 34678, 35096, 35113, 37239, 38673, 38981, 40060, 42000, 42385, 43392, 43494, 43961, 44380]


df_21= df_2[df_2['F'].isin(list_of_valu1)]

df_21.values
# Out:
# array([[3155, 2.0, 74.0,
#         'Isolation. No one to share ideas with. No context in which to view my own existance. Eating on my own. Lack of physical contact.'],
#        [3274, 2.0, 64.0,
#         "Loneliness is isolation - it's living in exile from the rest of the world.  It's having no one to talk to, to be with, to do things with, to ask for help.  It's like life shrinking and all there is is you, and it's terrifying.  "],
#        [8449, 1.0, 29.0,
#         "Feeling excluded from the 'real world.'  Not being able to ask for help or support. It may last forever. "],
#        [9741, 2.0, 46.0,
#         'I feel that loneliness is the absence of someone to share your good and bad times with, to conformable with your awkwardness and to connect with.'],
#        [11048, 2.0, 42.0, '-99'],
#        [12303, 2.0, 37.0,
#         'No one to share with. No one to talk to. Sadness. No one to love. '],
#        [14976, 2.0, 49.0,
#         'not having someone to share your life with to talk to in good and bad times'],
#        [16725, 2.0, 29.0, '-99'],
#        [18687, 2.0, 36.0, '-99'],
#        [21070, 2.0, 39.0,
#         'Coming home to an empty house. Isolation. Speaking to no-one for a weekend. Having no-one to talk to.'],
#        [21375, 2.0, 51.0,
#         'Little human contact. Low self esteem. Fear. Isolation. Self doubt.'],
#        [23939, 2.0, 41.0,
#         'To me, loneliness is the feeling of lack of pressence of people who care about you in your life.'],
#        [26013, 1.0, 49.0,
#         'Loneliness is every day of my life. I like solitude at times and places of my own choosing. I hate and resent daily loneliness that I did not choose.'],
#        [26585, 2.0, 63.0,
#         'Loneliness is the feeling of being disconnected from others, a lack of meaningful connection. It is also the sadness of feeling that you are not loved and cared for enough.'],
#        [28574, 1.0, 46.0,
#         'Loneliness is feeling empty, when by yourself, or with others. '],
#        [30375, 2.0, 46.0, 'Nobody to share thoughts and feelings with.'],
#        [31503, 2.0, 83.0,
#         'Feel isolated, removed from the world.  No one to talk to, so I talk to myself.'],
#        [31894, 1.0, 66.0,
#         "Emptiness. Feeling that it doesn't matter whether or not I exist. Having no purpose. Feeling alien.Sadness."],
#        [32023, 2.0, 53.0,
#         'Radio constantly on to avoid complete silence. Radio constantly on to provide a small percentage of my companionship needs. Radio constantly on to offer company when I come home. Dwelling on matters, over-analysing matters. Seeing the blacker side of life. Shortage of laughter. No-one to cook for. The place is the same when I come in as when I left it.'],
#        [32674, 2.0, 55.0,
#         'I am fine with my own company, I love it.  But in my current work situation I have no friends, social life, or even anyone in my peer group to talk to.  I used to have people I could ring but I work such long hours I am too exhausted to keep up friendships.'],
#        [33081, 2.0, 52.0,
#         "Isolation. Loneliness gets worse the longer it goes on. If I feel lonely for too long then I find it very hard to actually connect with anyone at all. It is not my default setting. I only started feeling lonely when I had a baby. I wasn't interested in mother and baby groups, my partner was away a lot, we lived in the middle of nowhere and I found it too easy to make excuses not to go out. I am quite sociable by nature, but the loneliness I endured/inflicted on myself led to depression and social anxiety."],
#        [34678, 2.0, nan,
#         'Endless days with no reason to get up or do anything. Feeling of being in a parallel existence to everyone else and that no one can hear or see me.'],
#        [35096, 2.0, 51.0,
#         'Not having someone who is able and willing to be able to talk to about the things that you are concerned with and those which you are interested in.'],
#        [35113, 2.0, 42.0, '-99'],
#        [37239, 1.0, 63.0, '-99'],
#        [38673, 2.0, 58.0,
#         'Having no one you can go to at a minutes notice. '],
#        [38981, 1.0, 61.0, '-99'],
#        [40060, 1.0, 54.0, 'Cut of from my community and society'],
#        [42000, 1.0, 47.0,
#         'Loneliness is not necessarily being alone but not being able to be yourself when you are with people you care about or people that say they care about you. Loneliness is acting that everything is fine when you are with friends. Loneliness is not being able to say what is really on your mind when you are with people especially when you want to. Loneliness is not having true community or feeling you belong. '],
#        [42385, 2.0, 70.0,
#         "Only since I got divorced do I feel really lonely, at times. Those times are when there aren't friends or neighbours around. I have no family here in uk, so my friends are everything to me but I never give them the idea that I'm desparate for company, but I have told my sister who lives in  Devon with her third husband. Am never bored, but I do get lonely when my air bnb guests goes home at the w/e. I just take myself off to a gallery, museum or film but usually by myself as most of my friends are either working, or being grandparents or away abroad or here in London. "],
#        [43392, 2.0, nan,
#         'A lack of companionship. Having to face a world that is often cold and uncaring, sometimes hostile, on one�??s own. Feeling that no one is interested nor cares about you. Having no one to encourage you, indeed having no one to tell you you screwed up.'],
#        [43494, 1.0, 66.0,
#         'Having no purpose beyond merely staying alive'],
#        [43961, 1.0, 44.0, '-99'],
#        [44380, 2.0, 57.0,
#         'Sadness.  Overthinking.  Dangerous.  Alone.  Unloved.']],
#       dtype=object)

# %%
list_of_valu2=[47, 553, 1301, 2442, 2767, 3721, 8547, 10016, 10176, 10705, 11633, 12911, 15747, 16320, 21485, 22600, 24436, 26059, 26511, 26906, 29812, 32189, 34388, 35634, 38774, 38900, 39464, 39935, 41451, 43855, 43892]

df_21= df_2[df_2['F'].isin(list_of_valu2)]

df_21.values
# Out:
# array([[47, 2.0, 19.0,
#         'Too much time lost in own thoughts. No people around to share thoughts with. Nobody to share happy memories with. Nobody to put stuff into perspective. '],
#        [553, 2.0, 58.0,
#         'it means having no one to talk to about my worries and problems. It means the person I live with constantly wearing headphones or pretending to be asleep or ignoring me in other ways. It means not having anyone to enjoy life with anymore. It means no longer feeling loved or needed.'],
#        [1301, 1.0, 44.0,
#         'I see two sides to loneliness. I am a lonely person - sometimes it feels great and more like enjoyable solitude. Other times it feels absolutely heart wrenchingly dreadful and the last thing I want is another moment alone.'],
#        [2442, 2.0, 47.0,
#         "Feeling isolated. Not being the most important person in someone else's life.  Not having anyone to do things with or go places with, nobody to go on holiday with."],
#        [2767, 1.0, 71.0,
#         'I feel that I am a social misfit. Thus spend huge amounts of time on my own and sometimes this is filled with positive activity, but at other times feel very isolated. Family links are there but geographical distance limits our contact. The unexpected and cruel death of my daughter '],
#        [3721, 2.0, 79.0, '-99'],
#        [8547, 2.0, 65.0,
#         'having no one to call and set up spontaneous plans. knowing people but not knowing them well enough to get into their life'],
#        [10016, 2.0, 51.0, '-99'],
#        [10176, 1.0, 55.0,
#         'Isolated. Unconnected. Sad. Alone. Depressed. Empty. '],
#        [10705, 2.0, 57.0,
#         'To me, loneliness is a longing or desire for another�??s company.  It can be specific - you wish a certain person could be with you since without that person, whatever you are doing is just not as vibrant.  Or it can be more generic - you just don�??t want to be alone; you want to be able to speak and be heard by someone else; you want the differentness that another person brings to your life.  Loneliness can lead to other emotions, which tend to be negative, if not checked.'],
#        [11633, 2.0, 22.0,
#         'No one to talk to or turn to for comfort and advice.'],
#        [12911, 1.0, 31.0,
#         'Not having someone to talk with . Not having anyone to go out with. Sitting at home most of the week.'],
#        [15747, 2.0, 41.0, '-99'],
#        [16320, 2.0, 34.0,
#         'no one to talk to from day to day, no social network.alone in morning. alone at night.'],
#        [21485, 2.0, 39.0, '-99'],
#        [22600, 2.0, 44.0,
#         'It means the lack of genuine connection with another human being'],
#        [24436, 1.0, 61.0,
#         'Its a dread type feeling going home to en empty house. Or starting a new club, activity and not knowing anyone. Its not having someone to talk to or confide in. It means I have to problem solve alone, I am indecisive so it causes me stress. I need someone to help me with choices. Not being invited on a family outing. '],
#        [26059, 1.0, 53.0,
#         "not having anyone to share life's moments and experiences with"],
#        [26511, 2.0, 30.0,
#         'Loneliness causes me to feel abandoned in and by life. I feel non existant and unfulfilled. '],
#        [26906, 2.0, 66.0,
#         "Feeling unsupported. Feeling totally responsible for every aspects of my life. Lacking physical closeness. Having no-one to share my problems. Having no-one to share my happiness. Having no-one to encourage me to do things I hesitate about. Having no-one on my side. Having no-one to go through all of life's experiences with me. Having no-one miss me if I'm not there. Having no-one who wants to make me happy.  Having no-one to make happy. Having no-one to do nice things for. Having no romance. Having a small life. Being sad. "],
#        [29812, 1.0, 62.0,
#         "Lonliness means not having someone to share the good and the bad with, feeling like there is noone who is interested in how your day was and feeling like you don't have a place to call home or anyone who you can call on "],
#        [32189, 2.0, 51.0, '-99'],
#        [34388, 2.0, 47.0, 'Isolated,being left out of things'],
#        [35634, 1.0, 45.0,
#         'It�??s a subjective feeling. It can be experienced even when surrounded by other people. Feeling if alienation. '],
#        [38774, 2.0, 56.0, 'Separation.h'],
#        [38900, 1.0, 46.0,
#         "Loneliness makes me feel isolated and not listened to. I feel quite invisible at times, verbally & physically. I feel that I've really missed out in my life having never had any close friends or best friends due to my early life trauma experiences within my family, preventing me from being able to put my trust in others. It saddens me hugely that I will never be able to regain the lost friendships throughout my life. I try not to dwell on it and have thrown myself into my family and work."],
#        [39464, 1.0, 47.0,
#         'Lonelness makes me feel sad.. Depressed. Isolated. Makes me feel Not Worthy. In my mind i lose confidence.'],
#        [39935, 2.0, 68.0,
#         'It makes you feel no one wants to know you or worthless'],
#        [41451, 2.0, 38.0, '-99'],
#        [43855, 2.0, 60.0, 'Being without my late husband.'],
#        [43892, 2.0, 69.0,
#         'Lack of someone special. Faling which lack of human company.']],
#       dtype=object)

# %%
36, 50, 66, 84, 96, 137, 140, 159, 175, 179, 182, 189, 195, 200, 203, 233, 269, 290, 328, 348, 389, 390, 449, 460, 469, 540, 585, 597, 631, 639, 686, 693, 725, 767, 824, 925, 943, 1026, 1047, 1061, 1093, 1107, 1164, 1172, 1185, 1224, 1241, 1261, 1278, 1316, 1346, 1348, 1446, 1465, 1492, 1505, 1631, 1657, 1699, 1705, 1718, 1771, 1778, 1808, 1829, 1845, 1870, 1872, 1892, 1906, 1938, 1950, 1984, 2031, 2054, 2061, 2087, 2093, 2150, 2155, 2162, 2194, 2250, 2286, 2311, 2316, 2321, 2323, 2344, 2374, 2467, 2480, 2500, 2562, 2601, 2629, 2656, 2662, 2704, 2783, 2912, 2998, 3024, 3046, 3058, 3070, 3073, 3082, 3116, 3157, 3165, 3313, 3320, 3362, 3373, 3418, 3419, 3441, 3477, 3480, 3485, 3633, 3696, 3735, 3761, 3774, 3882, 3896, 3934, 3963, 3984, 4057, 4097, 4148, 4152, 4153, 4172, 4190, 4242, 4268, 4295, 4316, 4317, 4333, 4410, 4416, 4477, 4523, 4526, 4561, 4565, 4570, 4606, 4641, 4642, 4648, 4656, 4699, 4741, 4767, 4807, 4823, 4838, 4875, 4901, 4904, 4908, 4919, 4952, 4992, 4996, 5038, 5154, 5156, 5228, 5257, 5293, 5314, 5321, 5331, 5432, 5474, 5531, 5578, 5671, 5740, 5761, 5891, 5903, 5950, 5965, 6109, 6308, 6315, 6325, 6377, 6391, 6425, 6438, 6462, 6482, 6491, 6492, 6499, 6549, 6556, 6570, 6601, 6632, 6676, 6743, 6778, 6810, 6830, 6899, 6951, 6958, 7018, 7038, 7074, 7108, 7179, 7187, 7212, 7226, 7227, 7254, 7312, 7316, 7327, 7333, 7349, 7364, 7380, 7429, 7446, 7506, 7508, 7528, 7555, 7560, 7641, 7659, 7661, 7755, 7767, 7775, 7785, 7795, 7816, 7825, 7842, 7864, 7874, 7879, 7884, 7894, 8046, 8048, 8061, 8077, 8098, 8153, 8156, 8272, 8288, 8291, 8340, 8383, 8410, 8413, 8415, 8471, 8477, 8486, 8513, 8533, 8558, 8617, 8620, 8632, 8633, 8655, 8687, 8693, 8726, 8763, 8780, 8846, 8853, 8865, 8869, 8871, 8884, 8894, 8901, 8964, 8967, 9052, 9068, 9086, 9097, 9133, 9167, 9177, 9190, 9207, 9340, 9365, 9446, 9469, 9488, 9611, 9636, 9691, 9721, 9726, 9768, 9798, 9870, 9876, 9941, 9948, 9977, 9985, 9992, 10019, 10041, 10044, 10045, 10122, 10146, 10175, 10182, 10232, 10253, 10256, 10288, 10322, 10376, 10377, 10385, 10402, 10424, 10448, 10453, 10466, 10522, 10534, 10600, 10608, 10648, 10674, 10685, 10718, 10777, 10779, 10784, 10811, 10837, 10864, 10911, 10913, 10929, 10952, 10953, 10988, 10991, 11009, 11038, 11066, 11071, 11097, 11098, 11111, 11185, 11193, 11209, 11230, 11258, 11268, 11274, 11277, 11305, 11335, 11343, 11370, 11376, 11390, 11394, 11398, 11458, 11568, 11613, 11615, 11640, 11704, 11750, 11756, 11768, 11777, 11788, 11810, 11853, 11875, 11915, 11923, 11931, 11979, 12006, 12007, 12085, 12095, 12114, 12144, 12154, 12162, 12172, 12216, 12224, 12234, 12255, 12297, 12358, 12398, 12479, 12482, 12533, 12541, 12607, 12648, 12661, 12679, 12704, 12705, 12739, 12741, 12742, 12747, 12795, 12820, 12865, 12918, 12932, 12934, 12936, 12974, 12990, 13004, 13038, 13044, 13049, 13087, 13107, 13147, 13161, 13166, 13189, 13203, 13205, 13230, 13286, 13338, 13393, 13434, 13442, 13472, 13512, 13536, 13543, 13588, 13672, 13674, 13708, 13724, 13752, 13771, 13802, 13832, 13919, 13978, 14023, 14061, 14127, 14143, 14172, 14184, 14214, 14235, 14250, 14253, 14257, 14274, 14315, 14349, 14353, 14389, 14458, 14468, 14489, 14493, 14505, 14554, 14621, 14647, 14702, 14711, 14742, 14768, 14773, 14821, 14833, 14845, 14854, 14900, 14921, 14968, 15077, 15094, 15137, 15153, 15181, 15193, 15298, 15302, 15323, 15383, 15392, 15400, 15417, 15436, 15488, 15539, 15599, 15619, 15752, 15774, 15815, 15845, 15866, 15869, 15901, 15968, 15976, 16085, 16088, 16115, 16159, 16173, 16188, 16235, 16246, 16289, 16332, 16358, 16422, 16438, 16479, 16482, 16489, 16495, 16547, 16549, 16563, 16669, 16693, 16695, 16716, 16735, 16745, 16748, 16782, 16792, 16873, 16892, 16895, 16902, 16956, 17031, 17035, 17050, 17058, 17074, 17088, 17115, 17183, 17222, 17227, 17259, 17296, 17298, 17318, 17349, 17417, 17463, 17588, 17620, 17747, 17754, 17765, 17799, 17819, 17833, 17853, 17880, 17915, 17924, 17949, 18060, 18064, 18073, 18089, 18109, 18128, 18133, 18152, 18165, 18185, 18214, 18287, 18299, 18300, 18304, 18308, 18364, 18413, 18431, 18471, 18475, 18486, 18512, 18515, 18535, 18581, 18588, 18636, 18676, 18680, 18689, 18706, 18746, 18801, 18802, 18830, 18839, 18880, 18887, 18936, 18949, 18969, 18988, 18993, 19005, 19011, 19170, 19229, 19244, 19271, 19286, 19316, 19318, 19335, 19348, 19360, 19373, 19386, 19441, 19471, 19505, 19564, 19598, 19620, 19621, 19642, 19707, 19710, 19742, 19753, 19765, 19794, 19823, 19834, 19929, 19968, 20007, 20014, 20015, 20048, 20121, 20122, 20146, 20152, 20158, 20187, 20198, 20201, 20298, 20368, 20410, 20420, 20422, 20434, 20481, 20508, 20513, 20524, 20564, 20597, 20637, 20644, 20779, 20788, 20894, 20900, 20930, 20935, 20951, 21008, 21027, 21035, 21072, 21108, 21136, 21141, 21174, 21230, 21315, 21330, 21335, 21352, 21419, 21436, 21454, 21455, 21504, 21529, 21576, 21613, 21646, 21656, 21676, 21679, 21728, 21735, 21791, 21794, 21803, 21814, 21818, 21836, 21841, 21868, 21885, 21903, 21930, 21949, 21970, 22014, 22019, 22025, 22056, 22090, 22182, 22188, 22190, 22195, 22210, 22221, 22322, 22331, 22337, 22382, 22421, 22435, 22441, 22473, 22522, 22546, 22556, 22615, 22628, 22706, 22791, 22813, 22858, 22888, 22909, 22916, 22918, 22989, 23069, 23114, 23168, 23242, 23269, 23276, 23296, 23314, 23328, 23342, 23398, 23465, 23491, 23560, 23564, 23600, 23606, 23661, 23850, 23857, 23860, 23869, 23878, 23992, 24006, 24113, 24119, 24155, 24287, 24288, 24315, 24317, 24360, 24400, 24404, 24492, 24500, 24521, 24526, 24530, 24536, 24571, 24590, 24642, 24695, 24709, 24713, 24754, 24756, 24763, 24792, 24800, 24817, 24826, 24827, 24837, 24856, 24875, 24893, 24936, 24960, 24967, 24976, 24989, 25015, 25063, 25077, 25085, 25101, 25104, 25110, 25180, 25183, 25212, 25222, 25239, 25281, 25375, 25378, 25394, 25415, 25427, 25537, 25556, 25597, 25699, 25705, 25748, 25806, 25853, 25864, 25904, 25909, 26001, 26049, 26064, 26084, 26091, 26097, 26105, 26137, 26151, 26171, 26237, 26267, 26283, 26292, 26302, 26323, 26357, 26395, 26519, 26531, 26595, 26611, 26656, 26661, 26683, 26715, 26738, 26759, 26777, 26784, 26789, 26790, 26817, 26822, 26933, 27003, 27021, 27044, 27152, 27165, 27173, 27180, 27201, 27209, 27211, 27233, 27252, 27255, 27267, 27292, 27427, 27474, 27484, 27505, 27517, 27519, 27535, 27604, 27616, 27684, 27688, 27701, 27764, 27803, 27828, 27831, 27899, 27904, 27905, 27924, 27954, 27983, 28026, 28040, 28044, 28056, 28058, 28076, 28147, 28162, 28175, 28181, 28248, 28267, 28302, 28316, 28322, 28369, 28372, 28444, 28477, 28505, 28544, 28614, 28635, 28682, 28699, 28712, 28734, 28765, 28788, 28799, 28864, 28891, 28919, 28926, 28932, 28940, 28955, 29001, 29019, 29097, 29099, 29102, 29126, 29153, 29160, 29170, 29206, 29241, 29282, 29327, 29332, 29362, 29385, 29469, 29505, 29527, 29574, 29587, 29612, 29637, 29645, 29650, 29668, 29690, 29728, 29792, 29841, 29845, 29905, 29920, 30012, 30057, 30092, 30128, 30145, 30158, 30170, 30270, 30477, 30488, 30685, 30760, 30798, 30806, 30817, 30850, 30861, 30889, 30899, 30915, 30998, 31016, 31044, 31069, 31098, 31118, 31145, 31176, 31225, 31289, 31362, 31400, 31433, 31438, 31462, 31592, 31630, 31641, 31714, 31731, 31737, 31739, 31773, 31797, 31853, 31912, 31935, 31949, 31952, 31954, 31995, 32078, 32112, 32152, 32188, 32190, 32203, 32209, 32258, 32259, 32283, 32356, 32404, 32412, 32413, 32513, 32514, 32577, 32579, 32598, 32644, 32691, 32714, 32771, 32836, 32845, 32919, 32920, 32946, 32991, 33079, 33088, 33098, 33101, 33103, 33142, 33215, 33220, 33250, 33266, 33286, 33352, 33377, 33398, 33484, 33491, 33532, 33562, 33588, 33591, 33618, 33701, 33739, 33743, 33767, 33802, 33804, 33826, 33853, 33854, 33860, 33917, 33936, 33937, 34009, 34027, 34040, 34044, 34061, 34078, 34116, 34123, 34144, 34179, 34194, 34202, 34274, 34312, 34324, 34329, 34331, 34367, 34389, 34398, 34449, 34491, 34538, 34609, 34633, 34670, 34727, 34729, 34780, 34832, 34867, 34929, 34936, 34940, 35038, 35052, 35055, 35129, 35140, 35167, 35198, 35261, 35280, 35299, 35336, 35370, 35380, 35504, 35519, 35608, 35639, 35646, 35686, 35745, 35747, 35750, 35764, 35789, 35792, 35811, 35837, 35920, 35953, 35969, 35988, 36036, 36055, 36076, 36124, 36132, 36136, 36226, 36248, 36259, 36277, 36378, 36402, 36448, 36464, 36469, 36513, 36536, 36581, 36604, 36626, 36639, 36671, 36712, 36782, 36801, 36869, 36899, 36923, 36933, 37009, 37057, 37062, 37066, 37070, 37083, 37094, 37095, 37100, 37106, 37148, 37185, 37191, 37204, 37218, 37222, 37234, 37238, 37265, 37276, 37287, 37292, 37309, 37315, 37323, 37355, 37380, 37383, 37396, 37424, 37438, 37472, 37487, 37529, 37564, 37581, 37601, 37614, 37627, 37631, 37643, 37669, 37671, 37676, 37711, 37727, 37739, 37745, 37805, 37819, 37838, 37864, 37868, 37873, 37890, 37926, 37968, 37989, 37997, 38007, 38070, 38082, 38157, 38159, 38167, 38192, 38208, 38213, 38219, 38224, 38263, 38297, 38299, 38327, 38364, 38380, 38416, 38436, 38465, 38486, 38490, 38499, 38505, 38515, 38598, 38650, 38683, 38698, 38708, 38739, 38778, 38783, 38821, 38825, 38859, 38876, 38899, 38903, 38954, 38961, 38978, 39054, 39067, 39091, 39132, 39153, 39168, 39186, 39201, 39229, 39253, 39259, 39272, 39276, 39284, 39299, 39328, 39374, 39381, 39382, 39386, 39398, 39400, 39420, 39422, 39440, 39445, 39459, 39461, 39517, 39519, 39522, 39564, 39567, 39648, 39685, 39731, 39772, 39870, 39894, 39907, 39909, 39929, 39933, 39940, 39973, 39997, 40000, 40086, 40112, 40122, 40139, 40153, 40154, 40157, 40221, 40267, 40321, 40339, 40364, 40377, 40421, 40436, 40451, 40473, 40485, 40487, 40505, 40508, 40520, 40525, 40553, 40554, 40611, 40639, 40653, 40657, 40681, 40691, 40705, 40706, 40711, 40725, 40767, 40781, 40785, 40791, 40811, 40847, 40854, 40858, 40874, 40876, 40903, 40907, 40916, 40934, 40944, 40949, 40951, 40960, 40961, 40964, 40981, 40991, 41001, 41012, 41019, 41020, 41021, 41023, 41026, 41027, 41075, 41090, 41094, 41100, 41131, 41141, 41159, 41171, 41181, 41190, 41210, 41212, 41213, 41223, 41226, 41251, 41261, 41283, 41289, 41307, 41343, 41366, 41413, 41417, 41426, 41439, 41440, 41457, 41490, 41503, 41507, 41512, 41519, 41547, 41568, 41615, 41635, 41644, 41645, 41652, 41693, 41696, 41711, 41756, 41806, 41872, 41887, 41909, 41952, 41975, 42010, 42019, 42071, 42086, 42091, 42096, 42101, 42141, 42148, 42168, 42186, 42190, 42197, 42198, 42208, 42210, 42217, 42239, 42257, 42279, 42289, 42349, 42352, 42360, 42370, 42378, 42397, 42412, 42435, 42448, 42452, 42457, 42485, 42509, 42544, 42586, 42602, 42614, 42620, 42654, 42657, 42661, 42699, 42710, 42748, 42749, 42763, 42770, 42783, 42800, 42807, 42818, 42836, 42849, 42872, 42874, 42875, 42897, 42942, 42945, 42964, 42983, 42995, 43016, 43022, 43026, 43031, 43041, 43054, 43057, 43073, 43075, 43086, 43111, 43120, 43121, 43126, 43138, 43162, 43174, 43192, 43210, 43214, 43236, 43247, 43256, 43300, 43309, 43330, 43333, 43336, 43339, 43422, 43451, 43464, 43467, 43488, 43500, 43522, 43530, 43576, 43603, 43609, 43637, 43640, 43648, 43650, 43686, 43697, 43698, 43744, 43746, 43760, 43761, 43779, 43808, 43811, 43827, 43841, 43871, 43881, 43882, 43898, 43921, 43955, 43959, 43979, 43985, 43988, 44000, 44013, 44019, 44042, 44050, 44085, 44089, 44090, 44092, 44099, 44105, 44116, 44126, 44128, 44161, 44168, 44180, 44185, 44198, 44210, 44229, 44251, 44262, 44273, 44291, 44292, 44347, 44374, 44381, 44390, 44400, 44443, 44445, 44446, 44517, 44536, 44616, 44622, 44626, 44641, 44644, 44657, 44669, 44683, 44703, 44707, 44746, 44791, 44828, 44838, 44854, 44865, 44866, 44869, 44879, 44903, 44929, 44932, 44991, 44995, 45025, 45027, 45078, 45080, 45091, 45104, 45111, 45120, 45141, 45155, 45169, 45171, 45182, 45208, 45212, 45222, 45251, 45273, 45277, 45285, 45309, 45333, 45387, 45392, 45394, 45402, 45406, 45427, 45429, 45440, 45443, 45449, 45463, 45464, 45477, 45504, 45507, 45522, 45551, 45553, 45557, 45621, 45628, 45633, 45636, 45654, 45669, 45682, 45689, 45703, 45705, 45716, 45725, 45737, 45756, 45759, 45762, 45776, 45779, 45786, 45789, 45807, 45811, 45816, 45818, 45822, 45830, 45833, 45836, 45839, 45841, 45847, 45854, 45859, 45873, 45881, 45885, 45888, 45893, 45900, 45906, 45910, 45911, 45925, 45990, 46004, 46006, 46010, 46017, 46020, 46024, 46035, 46049, 46055, 46061, 46074, 46095, 46098, 46102, 46110, 46131, 46132, 46145, 46157, 46224, 46226, 46227, 46234, 46265, 46278, 46279, 46289, 46300, 46319, 46326, 46328, 46331, 46332, 46339, 46368, 46377, 46584, 46796]

# %%
 # Custom coloring data based on the first variable
df_11 = pd.DataFrame(lens1, columns=["x", "y"])
df_11.head()

# %%
df_11["Circle"] = df_11["x"] ** 2 + df_11["y"] ** 2 < 0.25
df_11["Circle"] = df_11["Circle"].replace([False, True], ["A", "B"])

# %%
df_11.head()

# %%
node_elements = graph1.vs["node_elements"]

# %%
graph_1 = mapper.fit_transform(df_11[["x", "y"]])

# %%
node_elements

# %%
import matplotlib.pyplot as plt

km.draw_matplotlib(graph)
plt.show()

# %%
import sys
try:
    import pandas as pd
except ImportError as e:
    print("pandas is required for this example. Please install with conda or pip  and then try again.")
    sys.exit()

import numpy as np
import sklearn
from sklearn import ensemble
import kmapper as km
from kmapper.plotlyviz import *

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
feature_names = [c for c in clean_data.columns if c not in ["ID", "gender", "age", "Live_Alone","groupedmaritalstatus","Lonelycategrical","positivelonelinessgrouped","groupedtimealone",
                        "groupedhealth"]]

# %%
X = text ve
y = np.array(clean_data[["Live_Alone","groupedmaritalstatus","Lonelycategrical","positivelonelinessgrouped","groupedtimealone",
                        "groupedhealth"]])

# %%
X

# %%
import umap
import numpy as np
lens = umap.UMAP(n_components=2,
                  random_state=1).fit_transform(X)

# %%
embeddings.shape

# %%
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler

# %%
model= DBSCAN(eps = 0.6, min_samples = 25).fit(embeddings)

# %%
clean_data['cluster'] = model.labels_

# %% [markdown]
# n_clusters_ = len(set(clean_data['cluster'])) - (1 if -1 in clean_data['cluster'] else 0)
# n_noise_ = list(clean_data['cluster']).count(-1)

# %% [markdown]
# n_clusters_

# %% [markdown]
# #clean_data.to_csv('raw_cluster1.csv', index = False)

# %% [markdown]
# k = 17
# order_centroids = model.labels_
# terms = vectorizer.get_feature_names()
#
# for i in range(k):
#     print("Cluster %d:" % i)
#     for j in order_centroids[i, :10]: #print out 10 feature terms of each cluster
#         print (' %s' % terms[j])
#     print('------------')

# %%
##### from sklearn import metrics
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
# Data viz
from gtda.plotting import plot_point_cloud

# TDA magic
from gtda.mapper import (
    CubicalCover,
    make_mapper_pipeline,
    Projection,
    plot_static_mapper_graph,
    plot_interactive_mapper_graph,
    MapperInteractivePlotter
)

#Define filter
ump = umap.UMAP(n_neighbors=12,
                      min_dist=0.3,
                      metric='correlation')

# Define cover
cover = CubicalCover(n_intervals=10, overlap_frac=0.3)
# Choose clustering algorithm – default is DBSCAN
model= DBSCAN(eps = 0.6, min_samples = 20)
# Configure parallelism of clustering step
n_jobs = 1

# Initialise pipeline
pipe = make_mapper_pipeline(
    #filter_func=ump,
    cover=cover,
    clusterer=model,
    verbose=True,
    n_jobs=n_jobs,
)

# %%
reshape = embeddings.reshape(-1,1)

# %% [markdown]
# fig = plot_static_mapper_graph(pipe, reshape)
# fig.show(config={'scrollZoom': True})

# %%
plot_interactive_mapper_graph(pipe, embeddings)

# %%
reshape = embeddings
# Create the plotter object
MIP = MapperInteractivePlotter(pipe, reshape)

# Generate interactive widget
MIP.plot(color_data=reshape)

# %%
print("Attributes created by `.plot` and updated during the interactive session:\n",
      [attr for attr in dir(MIP) if attr.endswith("_") and attr[0] != "_"])

# %%
graph = pipe.fit_transform(reshape)
node_elements = graph.vs["node_elements"]
#print(f"There are {len(node_elements)} nodes.\nThe first node consists of row indices {node_elements[0]}.")

# %%
fig = plot_static_mapper_graph(
    pipe, embeddings, node_color_statistic=np.arange(len(node_elements))
)
#fig.show(config={'scrollZoom': True})

# %%
df = pd.DataFrame(reshape, columns=["x", "y"])
df.head()
df.shape

# %%
pipe.set_params(filter_func=Projection(columns=["x", "y"]));

# %%
fig = plot_static_mapper_graph(pipe, df, color_data=df)
fig.show(config={'scrollZoom': True})

# %%
df = pd.DataFrame(embeddings, columns=["x", "y"])

# %%
df["Circle"] = df["x"] ** 2 + df["y"] ** 2 < 0.25
df["Circle"] = df["Circle"].replace([False, True], ["A", "B"])

# %%
df

# %%
color_data = pd.get_dummies(df["Circle"], prefix="Circle")

fig = plot_static_mapper_graph(pipe, df[["x", "y"]], color_data=color_data)
fig.show(config={'scrollZoom': True})

# %%
graph = pipe.fit_transform(df[["x", "y"]])

# %%
graph.vs.attributes()

# %%
node_elements

# %% [markdown]
# for

# %%
node_id = 0
node_elements = graph.vs["node_elements"]

print(f"""
Node ID: {node_id}
Node elements: {node_elements[node_id]}
Data points: {embeddings[node_elements[node_id]]}
""")

# %%
node_elements

# %% [markdown]
# Clean_data

# %%
filter_func = np.sum

pipe = make_mapper_pipeline(
    filter_func=filter_func,
    cover=cover,
    clusterer=model,
    verbose=True,
    n_jobs=n_jobs,
)

# %%
fig = plot_static_mapper_graph(pipe, embeddings)
fig.show(config={'scrollZoom': True})
