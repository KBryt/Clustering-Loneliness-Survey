# %%
## Imports (code & data)

import pandas as pd
import yake
import math
import numpy as np


raw_data = pd.read_csv(r'C:\Users\BRIGHT\raw_age.csv')

# %%
# Renaming column

raw_data = raw_data.rename(columns = {'Q9_Loneliness_Meaning_Qual': 'response'})

# %%
clean_data = raw_data[raw_data['response'] != '-99']

# %%
clean_data['response'] = clean_data['response'].str.lower()
clean_data['response'] = clean_data['response'].str.replace('loneliness', '')
clean_data['response'] = clean_data['response'].str.replace('loneiness', '')
clean_data['response'] = clean_data['response'].str.replace('loneness', '')
clean_data['response'] = clean_data['response'].str.replace('aloneliness', '')
clean_data['response'] = clean_data['response'].str.replace('loneness', '')
clean_data['response'] = clean_data['response'].str.replace('/', ' ')
clean_data['response'] = clean_data['response'].str.replace('\n', ' ')
clean_data['response'] = clean_data['response'].str.replace('.', '')
clean_data['response'] = clean_data['response'].str.replace(',', '')
# Out:
# <ipython-input-4-1c5aab41cc2b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data['response'] = clean_data['response'].str.lower()
# <ipython-input-4-1c5aab41cc2b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data['response'] = clean_data['response'].str.replace('loneliness', '')
# <ipython-input-4-1c5aab41cc2b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data['response'] = clean_data['response'].str.replace('loneiness', '')
# <ipython-input-4-1c5aab41cc2b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data['response'] = clean_data['response'].str.replace('loneness', '')
# <ipython-input-4-1c5aab41cc2b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data['response'] = clean_data['response'].str.replace('aloneliness', '')
# <ipython-input-4-1c5aab41cc2b>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data['response'] = clean_data['response'].str.replace('loneness', '')
# <ipython-input-4-1c5aab41cc2b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data['response'] = clean_data['response'].str.replace('/', ' ')
# <ipython-input-4-1c5aab41cc2b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data['response'] = clean_data['response'].str.replace('\n', ' ')
# <ipython-input-4-1c5aab41cc2b>:9: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   clean_data['response'] = clean_data['response'].str.replace('.', '')
# <ipython-input-4-1c5aab41cc2b>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data['response'] = clean_data['response'].str.replace('.', '')
# <ipython-input-4-1c5aab41cc2b>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data['response'] = clean_data['response'].str.replace(',', '')

# %%
def getAnalysis(score):
    if  score <= -9:
        return 'Blank_Age'
    elif score <= 19:
        return '15-19'
    elif score <=39:
        return '20-39'
    elif score <=49:
        return '40-49'
    elif score <=59:
        return '50-59'
    elif score <=69:
        return '60-69'
    
    else:
        return '70 and above'
    
    
def getAnalysis1(score):
    if score == 1:
        return 'Male'
    elif score ==2:
        return 'Female'
    elif score ==3:
        return 'Others'
    elif score == -10:
        return 'Blank_Gender'
    else:
        return 'Prefer not to say'
    
clean_data['age_group'] = clean_data['age'].apply(getAnalysis)

    
clean_data['gender_cat'] = clean_data['gender'].apply(getAnalysis1)
#clean_data.head()
# Out:
# <ipython-input-5-33cc5b8c628b>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data['age_group'] = clean_data['age'].apply(getAnalysis)
# <ipython-input-5-33cc5b8c628b>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data['gender_cat'] = clean_data['gender'].apply(getAnalysis1)

# %% [markdown]
# def autolabel(rects):
#     """Attach a text label above each bar in *rects*, displaying its height."""
#     for rect in rects:
#         height = rect.get_height()
#         ax.annotate('{}'.format(height),
#                     xy=(rect.get_x() + rect.get_width() / 2, height),
#                     xytext=(0, 3),  # 3 points vertical offset
#                     textcoords="offset points",
#                     ha='center', va='bottom')

# %% [markdown]
# import pandas as pd
# countscldf = pd.DataFrame(clean_data['gender_cat'], columns = ["Cluster 0","Cluster 1","Cluster 2", "Cluster 3","Cluster 4"])

# %% [markdown]
# countscldf

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize = (30,10))
plt.subplot(1,2,1)
sns.countplot('age_group', hue = 'gender_cat', data = clean_data)

# %%
unique, count = np.unique(clean_data['age_group'], return_counts=True)

count = count.reshape(1, 7)

countscldf = pd.DataFrame(count, columns = ["Teen","Youth","Ma_youth", "Matured","Retiring","Pension", "Blank_age"])

countscldf

# %% [markdown]
# import seaborn as sns
# from matplotlib import pyplot as plt
# features = ['age_group', 'gender_cat']
#
# for f in features:
#     sns.countplot(x = f, data = clean_data, palette = 'Set3')# hue = 'Good Loan')
#     plt.xticks(rotation=45)
#     plt.show()

# %%
teens = clean_data[clean_data.age_group == '15-19']
youth = clean_data[clean_data.age_group == '20-39']
ma_youth = clean_data[clean_data.age_group == '40-49']
matured = clean_data[clean_data.age_group == '50-59']
Retiring = clean_data[clean_data.age_group == '60-69']
pension = clean_data[clean_data.age >= 60 ]
Blank_age = clean_data[clean_data.age_group == 'Blank_Age']

# %% [markdown]
# temale = teens[teens.gender_cat == 'Male']
# tefemale = teens[teens.gender_cat == 'Female']
#
# youmale = youth[youth.gender_cat == 'Male']
# ma_ymale = ma_youth[ma_youth.gender_cat == 'Male']
# matmale = matured[matured.gender_cat == 'Male']
# Retmale = Retiring[Retiring.gender_cat == 'Male']
#
# youfemale = youth[youth.gender_cat == 'Female']
# ma_yfemale = ma_youth[ma_youth.gender_cat == 'Female']
# matfemale = matured[matured.gender_cat == 'Female']
# Retfemale = Retiring[Retiring.gender_cat == 'Female']

# %% [markdown]
# Penmale = pension[pension.gender_cat == 'Male']
#
# penfemale = pension[pension.gender_cat == 'Female']
#
# Blank = clean_data[clean_data.age_group == 'BlankA']
#
# penpnts = Blank[Blank.gender_cat == 'Prefer not to say']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documentst = teens['response'].values.astype("U")
vectorizer = TfidfVectorizer(stop_words = ('english'))
featurest = vectorizer.fit_transform(documentst)

documentsy = youth['response'].values.astype("U")
vectorizer = TfidfVectorizer(stop_words = ('english'))
featuresy = vectorizer.fit_transform(documentsy)

documentsmy=ma_youth['response'].values.astype("U")
vectorizer = TfidfVectorizer(stop_words = ('english'))
featuresmy = vectorizer.fit_transform(documentsmy)

documentsm =matured['response'].values.astype("U")
vectorizer = TfidfVectorizer(stop_words = ('english'))
featuresm = vectorizer.fit_transform(documentsm)

documentsR = Retiring['response'].values.astype("U")
vectorizer = TfidfVectorizer(stop_words = ('english'))
featuresR = vectorizer.fit_transform(documentsR)

documentsp = pension['response'].values.astype("U")
vectorizer = TfidfVectorizer(stop_words = ('english'))
featuresp = vectorizer.fit_transform(documentsp)

documentsb = Blank_age['response'].values.astype("U")
vectorizer = TfidfVectorizer(stop_words = ('english'))
featuresb = vectorizer.fit_transform(documentsb)

# %%
from sklearn.decomposition import TruncatedSVD
#from scipy.sparse import csr_matrix
#import numpy as np
#np.random.seed(0)

svd = TruncatedSVD(n_components=5, n_iter=7, random_state=42)
T_SVDt = svd.fit_transform(featurest)

svd = TruncatedSVD(n_components=5, n_iter=7, random_state=42)
T_SVDy = svd.fit_transform(featuresy)

svd = TruncatedSVD(n_components=5, n_iter=7, random_state=42)
T_SVDmy = svd.fit_transform(featuresmy)

svd = TruncatedSVD(n_components=5, n_iter=7, random_state=42)
T_SVDm= svd.fit_transform(featuresm)

svd = TruncatedSVD(n_components=5, n_iter=7, random_state=42)
T_SVDR = svd.fit_transform(featuresR)

svd = TruncatedSVD(n_components=5, n_iter=7, random_state=42)
T_SVDp = svd.fit_transform(featuresp)

svd = TruncatedSVD(n_components=5, n_iter=7, random_state=42)
T_SVDb = svd.fit_transform(featuresb)

# %%
import umap
embeddingst = umap.UMAP(n_neighbors=12,
                      min_dist=0.3,
                      metric='correlation').fit_transform(T_SVDt)


embeddingsy = umap.UMAP(n_neighbors=12,
                      min_dist=0.3,
                      metric='correlation').fit_transform(T_SVDy)

embeddingsmy = umap.UMAP(n_neighbors=12,
                      min_dist=0.3,
                      metric='correlation').fit_transform(T_SVDmy)

embeddingsm = umap.UMAP(n_neighbors=12,
                      min_dist=0.3,
                      metric='correlation').fit_transform(T_SVDm)

embeddingsR = umap.UMAP(n_neighbors=12,
                      min_dist=0.3,
                      metric='correlation').fit_transform(T_SVDR)

embeddingsp = umap.UMAP(n_neighbors=12,
                      min_dist=0.3,
                      metric='correlation').fit_transform(T_SVDp)

embeddingsb = umap.UMAP(n_neighbors=12,
                      min_dist=0.3,
                      metric='correlation').fit_transform(T_SVDb)

# %%
import ripser
import teaspoon.TDA.Draw as Draw
diagramst = ripser.ripser(embeddingst)['dgms'][1]

diagramsy = ripser.ripser(embeddingsy)['dgms'][1]

diagramsmy = ripser.ripser(embeddingsmy)['dgms'][1]

diagramsm = ripser.ripser(embeddingsm)['dgms'][1]

diagramsR = ripser.ripser(embeddingsR)['dgms'][1]

diagramsp = ripser.ripser(embeddingsp)['dgms'][1]

diagramsb = ripser.ripser(embeddingsb)['dgms'][1]

# %%
import matplotlib.pyplot as plt
import persim
distance_bottleneck, matching = persim.bottleneck(diagramst, diagramsy, matching=True)
persim.bottleneck_matching(diagramst, diagramsy, matching, labels=['Teen $H_1$', 'Youth $H_1$'])
plt.show()

# %%
print(distance_bottleneck)
persim.bottleneck(diagramst, diagramsy)
# Out:
# 0.8506202697753906
# 0.8506202697753906

# %%
distance_bottleneck, matching = persim.bottleneck(diagramst, diagramsmy, matching=True)
persim.bottleneck_matching(diagramst, diagramsmy, matching, labels=['Teen $H_1$', 'Ma_Youth $H_1$'])
plt.show()

# %%
print(distance_bottleneck)
persim.bottleneck(diagramst, diagramsmy)
# Out:
# 0.6294517517089844
# 0.6294517517089844

# %%
distance_bottleneck, matching = persim.bottleneck(diagramst, diagramsm, matching=True)
persim.bottleneck_matching(diagramst, diagramsm, matching, labels=['Teen $H_1$', 'Matured $H_1$'])
plt.show()

# %%
print(distance_bottleneck)
persim.bottleneck(diagramst, diagramsm)
# Out:
# 0.501173734664917
# 0.501173734664917

# %%
distance_bottleneck, matching = persim.bottleneck(diagramst, diagramsR, matching=True)
persim.bottleneck_matching(diagramst, diagramsR, matching, labels=['Teen $H_1$', 'Retiring'])
plt.show()

# %%
print(distance_bottleneck)
persim.bottleneck(diagramst, diagramsR)
# Out:
# 0.5163798332214355
# 0.5163798332214355

# %%
distance_bottleneck, matching = persim.bottleneck(diagramst, diagramsp, matching=True)
persim.bottleneck_matching(diagramst, diagramsp, matching, labels=['Teen $H_1$', 'Pension $H_1$'])
plt.show()

# %%
print(distance_bottleneck)
persim.bottleneck(diagramst, diagramsp)
# Out:
# 0.8506202697753906
# 0.8506202697753906

# %%
distance_bottleneck, matching = persim.bottleneck(diagramst, diagramsb, matching=True)
persim.bottleneck_matching(diagramst, diagramsb, matching, labels=['Teen $H_1$', 'BlankAge $H_1$'])
plt.show()

# %%
print(distance_bottleneck)
persim.bottleneck(diagramst, diagramsb)
# Out:
# 0.8809207081794739
# 0.8809207081794739

# %%
distance_bottleneck, matching = persim.bottleneck(diagramsy, diagramsmy, matching=True)
persim.bottleneck_matching(diagramsy, diagramsmy, matching, labels=['Youth $H_1$', 'Ma_Youth $H_1$'])
plt.show()

print(distance_bottleneck)
persim.bottleneck(diagramsy, diagramsmy)
# Out:
# 0.9450517892837524
# 0.9450517892837524

# %%
distance_bottleneck, matching = persim.bottleneck(diagramsy, diagramsm, matching=True)
persim.bottleneck_matching(diagramsy, diagramsm, matching, labels=['Youth $H_1$', 'Matured $H_1$'])
plt.show()

# %%
print(distance_bottleneck)
persim.bottleneck(diagramsy, diagramsm)
# Out:
# 0.6801190376281738
# 0.6801190376281738

# %%
distance_bottleneck, matching = persim.bottleneck(diagramsy, diagramsR, matching=True)
persim.bottleneck_matching(diagramsy, diagramsR, matching, labels=['Youth $H_1$', 'Retiring $H_1$'])
plt.show()

# %%
print(distance_bottleneck)
persim.bottleneck(diagramsy, diagramsR)
# Out:
# 0.5219268202781677
# 0.5219268202781677

# %%
distance_bottleneck, matching = persim.bottleneck(diagramsy, diagramsp, matching=True)
persim.bottleneck_matching(diagramsy, diagramsp, matching, labels=['Youth $H_1$', 'Pension $H_1$'])
plt.show()

# %%
print(distance_bottleneck)
persim.bottleneck(diagramsy, diagramsp)
# Out:
# 0.4462912082672119
# 0.4462912082672119

# %%
distance_bottleneck, matching = persim.bottleneck(diagramsy, diagramsb, matching=True)
persim.bottleneck_matching(diagramsy, diagramsb, matching, labels=['Youth $H_1$', 'BlankAge $H_1$'])
plt.show()

# %%
print(distance_bottleneck)
persim.bottleneck(diagramsy, diagramsb)
# Out:
# 0.983018159866333
# 0.983018159866333

# %%
distance_bottleneck, matching = persim.bottleneck(diagramsmy, diagramsm, matching=True)
persim.bottleneck_matching(diagramsmy, diagramsm, matching, labels=['Ma_Youth $H_1$', 'Matured $H_1$'])
plt.show()

# %%
print(distance_bottleneck)
persim.bottleneck(diagramsmy, diagramsm)
# Out:
# 0.7960959672927856
# 0.7960959672927856

# %%
distance_bottleneck, matching = persim.bottleneck(diagramsmy, diagramsR, matching=True)
persim.bottleneck_matching(diagramsmy, diagramsR, matching, labels=['Ma_Youth $H_1$', 'Retiring $H_1$'])
plt.show()

# %%
print(distance_bottleneck)
persim.bottleneck(diagramsmy, diagramsR)
# Out:
# 0.6294517517089844
# 0.6294517517089844

# %%
distance_bottleneck, matching = persim.bottleneck(diagramsmy, diagramsp, matching=True)
persim.bottleneck_matching(diagramsmy, diagramsp, matching, labels=['Retiring $H_1$', 'Pension $H_1$'])
plt.show()

# %%
print(distance_bottleneck)
persim.bottleneck(diagramsmy, diagramsp)
# Out:
# 1.0591331869363785
# 1.0591331869363785

# %%
distance_bottleneck, matching = persim.bottleneck(diagramsmy, diagramsb, matching=True)
persim.bottleneck_matching(diagramsmy, diagramsb, matching, labels=['Ma_Youth $H_1$', 'BlankAge $H_1$'])
plt.show()

# %%
print(distance_bottleneck)
persim.bottleneck(diagramsmy, diagramsb)
# Out:
# 0.6679118871688843
# 0.6679118871688843

# %%
distance_bottleneck, matching = persim.bottleneck(diagramsm, diagramsR, matching=True)
persim.bottleneck_matching(diagramsm, diagramsR, matching, labels=['Matured $H_1$', 'Retiring $H_1$'])
plt.show()

# %%
print(distance_bottleneck)
persim.bottleneck(diagramsm, diagramsR)
# Out:
# 0.7960959672927856
# 0.7960959672927856

# %%
distance_bottleneck, matching = persim.bottleneck(diagramsm, diagramsp, matching=True)
persim.bottleneck_matching(diagramsm, diagramsp, matching, labels=['Matured $H_1$', 'Pension $H_1$'])
plt.show()

# %%
print(distance_bottleneck)
persim.bottleneck(diagramsm, diagramsp)
# Out:
# 0.7960959672927856
# 0.7960959672927856

# %%
distance_bottleneck, matching = persim.bottleneck(diagramsm, diagramsb, matching=True)
persim.bottleneck_matching(diagramsm, diagramsb, matching, labels=['Matured $H_1$', 'BlankAge $H_1$'])
plt.show()

# %%
print(distance_bottleneck)
persim.bottleneck(diagramsm, diagramsb)
# Out:
# 0.7703046798706055
# 0.7703046798706055

# %%
distance_bottleneck, matching = persim.bottleneck(diagramsR, diagramsp, matching=True)
persim.bottleneck_matching(diagramsR, diagramsp, matching, labels=['Retiring $H_1$', 'Pension $H_1$'])
plt.show()

# %%
print(distance_bottleneck)
persim.bottleneck(diagramsR, diagramsp)
# Out:
# 0.5917969942092896

# %%
distance_bottleneck, matching = persim.bottleneck(diagramsR, diagramsb, matching=True)
persim.bottleneck_matching(diagramsR, diagramsb, matching, labels=['Retiring $H_1$', 'BlankAge $H_1$'])
plt.show()

# %%
print(distance_bottleneck)
persim.bottleneck(diagramsR, diagramsb)

# %%
distance_bottleneck, matching = persim.bottleneck(diagramsp, diagramsb, matching=True)
persim.bottleneck_matching(diagramsp, diagramsb, matching, labels=['Pension $H_1$', 'BlankAge $H_1$'])
plt.show()

# %%
print(distance_bottleneck)
persim.bottleneck(diagramsp, diagramsb)

# %%
distance_bottleneck, matching = persim.bottleneck(diagramsmy, diagramsR, matching=True)
persim.bottleneck_matching(diagramsmy, diagramsR, matching, labels=['Ma_Youth $H_1$', 'Retiring $H_1$'])
plt.show()

# %%
print(distance_bottleneck)
persim.bottleneck(diagramsmy, diagramsp)

# %%
distance_bottleneck, matching = persim.bottleneck(diagramsmy, diagramsR, matching=True)
persim.bottleneck_matching(diagramsmy, diagramsR, matching, labels=['Ma_Youth $H_1$', 'Retiring $H_1$'])
plt.show()

# %%
print(distance_bottleneck)
persim.bottleneck(diagramsmy, diagramsp)

# %% [markdown]
# distance_bottleneck, matching = persim.bottleneck(diagrams2, diagramsc, matching=True)
# persim.bottleneck_matching(diagrams2, diagramsc, matching, labels=['Youth $H_1$', 'Pension $H_1$'])
# plt.show()

# %%
print(distance_bottleneck)

# %% [markdown]
# distance_bottleneck, matching = persim.bottleneck(diagrams1, diagrams2, diagrams, diagramsa, diagramsb,
#                                                    diagramsc, matching=True)
# persim.bottleneck_matching([diagrams1, diagrams2, diagrams, diagramsa, diagramsb, diagramsc],
#                      labels=['Teens $H_1$', 'Youth $H_1$','Ma_youth $H_1$','Matured $H_1$','Retiring $H_1$','Pension $H_1$'])

# %%
persim.bottleneck_matching([diagrams1, diagrams2, diagrams, diagramsa, diagramsb, diagramsc], 
                     labels=['Teens $H_1$', 'Youth $H_1$','Ma_youth $H_1$','Matured $H_1$','Retiring $H_1$','Pension $H_1$'])

# %%
print(distance_bottleneck)
#persim.bottleneck(dgm_clean, dgm_noisy)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (15,5))
plt.scatter(T_SVD[:,0], T_SVD[:,1], label = 'P1')
plt.scatter(T_SVDa[:,0],T_SVDa[:,1], label = 'P2')
plt.scatter(T_SVDb[:,0],T_SVDb[:,1], label = 'P3')
plt.scatter(T_SVDc[:,0],T_SVDc[:,1], label = 'P3')
plt.axis('equal')
plt.legend()

# %%
#--- this is the main persistence computation workhorse
import ripser
# from persim import plot_diagrams
import persim

diagrams1 = ripser.ripser(T_SVD)['dgms']

# %%
drawTDAtutorial(,diagrams,R=2.5)

# %%
diagrams2 = ripser.ripser(T_SVDa)['dgms']

# %%
diagrams3 = ripser.ripser(T_SVDb)['dgms']

# %%
Compute bottleneck distance using scikit-tda
distance_bottleneck, (matching, D) = persim.bottleneck(diagrams1[1], diagrams2[1],  matching=True)
persim.visuals.bottleneck_matching(diagrams1[1], diagrams2[1], matching, labels=['Clean $H_1$', 'Noisy $H_1$'])
print('The bottleneck distance is', distance_bottleneck)
# print(matching)
# print(D)

# %%
diagrams3 = ripser.ripser(T_SVDb)['dgms']
diagrams4 = ripser.ripser(T_SVDc)['dgms']

# %% [markdown]
# Draw.drawDgm(diagrams1[1])
# Draw.drawDgm(diagrams2[1])
# Draw.drawDgm(diagrams3[1])
# Draw.drawDgm(diagrams4[1])

# %%
import teaspoon.MakeData.PointCloud as makePtCloud
r = 1
R = 2
P = makePtCloud.Annulus(embeddings, r=r, R=R, seed=None) # teaspoon data generation
plt.scatter(P[:,0],P[:,1])
# print(P)

# %%
#--- this is the main persistence computation workhorse
import ripser
# from persim import plot_diagrams
import persim

# %%
import matplotlib.pyplot as plt

x_axis = [o[0] for o in features.toarray()]
y_axis = [o[1] for o in features.toarray()]

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

def drawTDAtutorial(features, diagrams, R = 2):
    fig, axes = plt.subplots(nrows=1, ncols=3,figsize = (20,5))

    # Draw point cloud 
    plt.sca(axes[0])
    plt.title('Point Cloud')
    plt.scatter(x_axis, y_axis)

    # Draw diagrams
    plt.sca(axes[1])
    plt.title('0-dim Diagram')
    Draw.drawDgm(diagrams[0])

    plt.sca(axes[2])
    plt.title('1-dim Diagram')
    Draw.drawDgm(diagrams[1])
    plt.axis([0,R,0,R])

# %%
import teaspoon.TDA.Draw as Draw
diagrams = ripser.ripser(features)['dgms']

# Draw stuff
drawTDAtutorial(features,diagrams)

# %%
kw_model.extract_keywords(words6, keyphrase_ngram_range=(3, 3), stop_words='english', 
                              use_maxsum=True, nr_candidates=20, top_n=5)

# %%
kw_model.extract_keywords(words6, keyphrase_ngram_range=(1, 1))

# %%
kw_model.extract_keywords(words6, keyphrase_ngram_range=(1, 2))

# %%
keyy

# %%
kw_model.extract_keywords(words6, keyphrase_ngram_range=(3, 3), stop_words='english', 
                              use_maxsum=True, nr_candidates=20, top_n=10)

# %%
kw_model.extract_keywords(clean_data['response'], highlight=True)

# %% [markdown]
# from os import path
# from PIL import Image
# from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# %matplotlib inline
#
# import matplotlib
# import numpy as np
# import matplotlib.pyplot as plt
# import matplotlib.pyplot as plt
#
#
# wordcloud = WordCloud(max_font_size=30, max_words=30000, background_color="white").generate(words6)
# plt.figure(figsize = (15, 15), facecolor = None)
#
# plt.imshow(wordcloud, interpolation="bilinear")
# plt.axis("off")
# plt.show()
#
# wordcloud.to_file('loneliness_wordcloud.png')

# %% [markdown]
#  import yake
# kw_extractor = yake.KeywordExtractor()
#
# language = "en"
# max_ngram_size = 5
# deduplication_threshold = 0.9
# numOfKeywords = 10
# custom_kw_extractor = yake.KeywordExtractor(lan=language, n=max_ngram_size, dedupLim=deduplication_threshold, top=numOfKeywords, features=None)
# keywords = custom_kw_extractor.extract_keywords(words6)
# for kw in keywords:
#      print(kw)

# %%
import yake
kw_extractor = yake.KeywordExtractor()

language = "en"
max_ngram_size = 1
deduplication_threshold = 0.9
numOfKeywords = 5
custom_kw_extractor = yake.KeywordExtractor(lan=language, n=max_ngram_size, dedupLim=deduplication_threshold, top=numOfKeywords, features=None)
keywords = custom_kw_extractor.extract_keywords(words6)
for kw in keywords:
     print(kw)

# %%
features.shape

# %%
from sklearn.decomposition import TruncatedSVD
#from scipy.sparse import csr_matrix
#import numpy as np
#np.random.seed(0)
#
svd = TruncatedSVD(n_components=5, n_iter=7, random_state=42)
T_SVD = svd.fit_transform(features)

# %%
T_SVD.shape

# %%
import matplotlib.pyplot as plt

x_axis = [o[0] for o in T_SVD]
y_axis = [o[1] for o in T_SVD]


fig, ax = plt.subplots(figsize=(50, 50))

ax.scatter(x_axis, y_axis, color = 'black', alpha = 0.5 )

# %%
import numpy
from sklearn.manifold import TSNE

# %%
tsne = TSNE(n_components=2, perplexity=20)
data_2d = tsne.fit_transform(T_SVD)

# %%
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler

# %%
model= DBSCAN(eps = 0.7, min_samples = 25).fit(data_2d)

# %%
cluster = model.labels_

# %%
core_samples_mask = np.zeros_like(cluster, dtype=bool)
core_samples_mask[model.core_sample_indices_] = True
core_samples_mask

# %%
n_clusters_ = len(set(cluster)) - (1 if -1 in cluster else 0)
n_noise_ = list(cluster).count(-1)

# %%
print("Estimated number of clusters: %d" % n_clusters_)
print("Estimated number of noise points: %d" % n_noise_)

# %%
from sklearn.metrics import silhouette_score
data_2d_cluster = (data_2d["cluster"] >= 0)

silhouette_score(data_2d_cluster[[x_axis, y_axis]], data_2d_cluster[(cluster)] )

# %%
x_axis = [o[0] for o in data_2d]
y_axis = [o[1] for o in data_2d]

# %%
n_noise_

# %%
x_axis = [o[0] for o in data_2d]
y_axis = [o[1] for o in data_2d]


fig, ax = plt.subplots(figsize=(50, 50))

ax.scatter(x_axis, y_axis, color = 'black', alpha = 0.5 )

# %%
unique_labels = set(cluster)
plt.figure(figsize=(30,30))

colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(unique_labels))]
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    respondent_mask = cluster == k
    
    xy = data_2d[respondent_mask & core_samples_mask]
    plt.plot(
        xy[:, 0],
        xy[:, 1],
        "o",
        markerfacecolor=tuple(col),
        markeredgecolor="k",
        markersize=14,
    )

    xy = data_2d[respondent_mask & ~core_samples_mask]
    plt.plot(
        xy[:, 0],
        xy[:, 1],
        "o",
        markerfacecolor=tuple(col),
        markeredgecolor="k",
        markersize=6,
    )

plt.title("Estimated number of clusters: %d" % n_clusters_)
plt.show()

# %% [markdown]
# from ggplot import *
#
# from sklearn.metrics import silhouette_score
#
# %matplotlib inline
#
# from pandas import Timestamp
#
# labslist = ["Noise"]
# labslist = labslist + ["Cluster" + str(i) for i in range(1, len(set(cluster)))]
#
# cluster = model.labels_
#
# x_axis = [o[0] for o in data_2d]
# y_axis = [o[1] for o in data_2d]
#
#
# ggplot(data_2d, aes(x_axis, y_axis, color = "factor(cluster)")) + geom_point() + theme_minimal()

# %%
# Plot the points with colors
plt.figure(figsize=(30,30))

for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = 'k'

    class_member_mask = (cluster == k)
   
    # Plot the datapoints that are clustered
    xy = data_2d[class_member_mask & core_samples_mask]
    plt.scatter(xy[:, 0], xy[:, 1],s=50, c=[col], marker=u'o', alpha=0.2, )

    # Plot the outliers
    xy= data_2d[class_member_mask & ~core_samples_mask]
    plt.scatter(xy[:, 0], xy[:, 1],s=50, c=[col], marker=u'o', alpha=0.2, )

# %%
from sklearn import metrics
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
# Data viz
from gtda.plotting import plot_point_cloud

# TDA magic
from gtda.mapper import (
    CubicalCover,
    make_mapper_pipeline,
    Projection,
    plot_static_mapper_graph,
    plot_interactive_mapper_graph,
    MapperInteractivePlotter
)


# Define cover
cover = CubicalCover(n_intervals=10, overlap_frac=0.5)
# Choose clustering algorithm – default is DBSCAN

# Configure parallelism of clustering step
n_jobs = 1

# Initialise pipeline
pipe = make_mapper_pipeline(
    cover=cover,
    clusterer=model,
    verbose=False,
    n_jobs=n_jobs,
)

# %%
fig = plot_static_mapper_graph(pipe, data_2d)
fig.show(config={'scrollZoom': True})

# %%
from sklearn.metrics import silhouette_score
data_2d_cluster = (data_2d["cluster"] >= 0)

silhouette_score(data_2d_cluster[[x_axis, y_axis]], data_2d_cluster[(cluster)] )

# %%
model1= DBSCAN(eps = 0.6, min_samples = 25)
cover = CubicalCover(n_intervals=10, overlap_frac=0.3)
# Choose clustering algorithm – default is DBSCAN

# Configure parallelism of clustering step
n_jobs = 1

# Initialise pipeline
pipe = make_mapper_pipeline(
    cover=cover,
    clusterer=model1,
    verbose=False,
    n_jobs=n_jobs,
)

fig = plot_static_mapper_graph(pipe, data_2d)
fig.show(config={'scrollZoom': False})

# %%
plot_interactive_mapper_graph(pipe, data_2d)

# %%
# Create the plotter object
MIP = MapperInteractivePlotter(pipe, data_2d)

# Generate interactive widget
MIP.plot(color_data=data_2d)

# %%
print("Attributes created by `.plot` and updated during the interactive session:\n",
      [attr for attr in dir(MIP) if attr.endswith("_") and attr[0] != "_"])

# %%
graph = pipe.fit_transform(data_2d)
node_elements = graph.vs["node_elements"]
print(f"There are {len(node_elements)} nodes.\nThe first node consists of row indices {node_elements[0]}.")

# %%
fig = plot_static_mapper_graph(
    pipe, data_2d, node_color_statistic=np.arange(len(node_elements))
)
fig.show(config={'scrollZoom': True})

# %%
df = pd.DataFrame(data_2d, columns=["x", "y"])
df

# %%
pipe.set_params(filter_func=Projection(columns=["x", "y"]));

# %%
fig = plot_static_mapper_graph(pipe, df, color_data=df)
fig.show(config={'scrollZoom': True})

# %%
df["Circle"] = df["x"] ** 2 + df["y"] ** 2 < 0.25
df["Circle"] = df["Circle"].replace([False, True], ["A", "B"])

# %%
color_data = pd.get_dummies(df["Circle"], prefix="Circle")

fig = plot_static_mapper_graph(pipe, df[["x", "y"]], color_data=color_data)
fig.show(config={'scrollZoom': True})

# %%
graph = pipe.fit_transform(df[["x", "y"]])

# %%
graph.vs.attributes()

# %%
node_id = 0
node_elements = graph.vs["node_elements"]

print(f"""
Node ID: {node_id}
Node elements: {node_elements[node_id]}
Data points: {data_2d[node_elements[node_id]]}
""")

# %%
filter_func = np.sum

pipe = make_mapper_pipeline(
    filter_func=filter_func,
    cover=cover,
    clusterer=model,
    verbose=True,
    n_jobs=n_jobs,
)

# %%
fig = plot_static_mapper_graph(pipe, data_2d)
fig.show(config={'scrollZoom': True})

# %%
Newcluster = model.labels_
Newcluster

# %% [markdown]
# k = 5
# order_centroids = model.cluster_centers_.argsort()[:, ::-1]
# terms = vectorizer.get_feature_names()
#
# for i in range(k):
#     print("Cluster %d:" % i)
#     for j in order_centroids[i, :10]: #print out 10 feature terms of each cluster
#         print (' %s' % terms[j])
#     print('------------')

# %%
raw_data['Clusters'] = hc.labels_
